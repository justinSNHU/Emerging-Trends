# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.8265651079747222, score: 42
# Scores: (min: 16, avg: 29, max: 42)
#
# Run: 3, exploration: 0.7901049725470279, score: 10
# Scores: (min: 10, avg: 22.666666666666668, max: 42)
#
# Run: 4, exploration: 0.7183288830986236, score: 20
# Scores: (min: 10, avg: 22, max: 42)
#
# Run: 5, exploration: 0.6763948591909945, score: 13
# Scores: (min: 10, avg: 20.2, max: 42)
#
# Run: 6, exploration: 0.5704072587541458, score: 35
# Scores: (min: 10, avg: 22.666666666666668, max: 42)
#
# Run: 7, exploration: 0.4858739637363176, score: 33
# Scores: (min: 10, avg: 24.142857142857142, max: 42)
#
# Run: 8, exploration: 0.46211964903917074, score: 11
# Scores: (min: 10, avg: 22.5, max: 42)
#
# Run: 9, exploration: 0.4417353564707963, score: 10
# Scores: (min: 10, avg: 21.11111111111111, max: 42)
#
# Run: 10, exploration: 0.4180382776616619, score: 12
# Scores: (min: 10, avg: 20.2, max: 42)
#
# Run: 11, exploration: 0.39166620452737816, score: 14
# Scores: (min: 10, avg: 19.636363636363637, max: 42)
#
# Run: 12, exploration: 0.3420891339682016, score: 28
# Scores: (min: 10, avg: 20.333333333333332, max: 42)
#
# Run: 13, exploration: 0.3079101286968243, score: 22
# Scores: (min: 10, avg: 20.46153846153846, max: 42)
#
# Run: 14, exploration: 0.28417984116121187, score: 17
# Scores: (min: 10, avg: 20.214285714285715, max: 42)
#
# Run: 15, exploration: 0.2609670281126685, score: 18
# Scores: (min: 10, avg: 20.066666666666666, max: 42)
#
# Run: 16, exploration: 0.231387331601191, score: 25
# Scores: (min: 10, avg: 20.375, max: 42)
#
# Run: 17, exploration: 0.19513012515638165, score: 35
# Scores: (min: 10, avg: 21.235294117647058, max: 42)
#
# Run: 18, exploration: 0.1730128104744653, score: 25
# Scores: (min: 10, avg: 21.444444444444443, max: 42)
#
# Run: 19, exploration: 0.1557266555690826, score: 22
# Scores: (min: 10, avg: 21.473684210526315, max: 42)
#
# Run: 20, exploration: 0.14590259167570602, score: 14
# Scores: (min: 10, avg: 21.1, max: 42)
#
# Run: 21, exploration: 0.11999500148501063, score: 40
# Scores: (min: 10, avg: 22, max: 42)
#
# Run: 22, exploration: 0.11527836319047392, score: 9
# Scores: (min: 9, avg: 21.40909090909091, max: 42)
#
# Run: 23, exploration: 0.10746596228306791, score: 15
# Scores: (min: 9, avg: 21.130434782608695, max: 42)
#
# Run: 24, exploration: 0.10018300685223579, score: 15
# Scores: (min: 9, avg: 20.875, max: 42)
#
# Run: 25, exploration: 0.08619587539414532, score: 31
# Scores: (min: 9, avg: 21.28, max: 42)
#
# Run: 26, exploration: 0.07566352740075044, score: 27
# Scores: (min: 9, avg: 21.5, max: 42)
#
# Run: 27, exploration: 0.06575561514114299, score: 29
# Scores: (min: 9, avg: 21.77777777777778, max: 42)
#
# Run: 28, exploration: 0.05327239673939179, score: 43
# Scores: (min: 9, avg: 22.535714285714285, max: 43)
#
# Run: 29, exploration: 0.04794981455780219, score: 22
# Scores: (min: 9, avg: 22.517241379310345, max: 43)
#
# Run: 30, exploration: 0.035673744367776934, score: 60
# Scores: (min: 9, avg: 23.766666666666666, max: 60)
#
# Run: 31, exploration: 0.032595988006089364, score: 19
# Scores: (min: 9, avg: 23.612903225806452, max: 60)
#
# Run: 32, exploration: 0.027214167668287145, score: 37
# Scores: (min: 9, avg: 24.03125, max: 60)
#
# Run: 33, exploration: 0.021394538952450012, score: 49
# Scores: (min: 9, avg: 24.78787878787879, max: 60)
#
# Run: 34, exploration: 0.018223908064988973, score: 33
# Scores: (min: 9, avg: 25.029411764705884, max: 60)
#
# Run: 35, exploration: 0.013832827362230486, score: 56
# Scores: (min: 9, avg: 25.914285714285715, max: 60)
#
# Run: 36, exploration: 0.01, score: 66
# Scores: (min: 9, avg: 27.02777777777778, max: 66)
#
# Run: 37, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 29.35135135135135, max: 113)
#
# Run: 38, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 30.92105263157895, max: 113)
#
# Run: 39, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 34.53846153846154, max: 172)
#
# Run: 40, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 37.85, max: 172)
#
# Run: 41, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 40.26829268292683, max: 172)
#
# Run: 42, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 43.095238095238095, max: 172)
#
# Run: 43, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 45.348837209302324, max: 172)
#
# Run: 44, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 47.70454545454545, max: 172)
#
# Run: 45, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 49.733333333333334, max: 172)
#
# Run: 46, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 51.41304347826087, max: 172)
#
# Run: 47, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 53.1063829787234, max: 172)
#
# Run: 48, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 55.166666666666664, max: 172)
#
# Run: 49, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 56.51020408163265, max: 172)
#
# Run: 50, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 57.9, max: 172)
#
# Run: 51, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 59.294117647058826, max: 172)
#
# Run: 52, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 60.80769230769231, max: 172)
#
# Run: 53, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 61.83018867924528, max: 172)
#
# Run: 54, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 63.01851851851852, max: 172)
#
# Run: 55, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 64.45454545454545, max: 172)
#
# Run: 56, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 65.51785714285714, max: 172)
#
# Run: 57, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 66.85964912280701, max: 172)
#
# Run: 58, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 67.87931034482759, max: 172)
#
# Run: 59, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 68.8135593220339, max: 172)
#
# Run: 60, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 69.66666666666667, max: 172)
#
# Run: 61, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 70.59016393442623, max: 172)
#
# Run: 62, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 71.46774193548387, max: 172)
#
# Run: 63, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 72.0952380952381, max: 172)
#
# Run: 64, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 73.046875, max: 172)
#
# Run: 65, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 74.18461538461538, max: 172)
#
# Run: 66, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 74.71212121212122, max: 172)
#
# Run: 67, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 75.5223880597015, max: 172)
#
# Run: 68, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 75.98529411764706, max: 172)
#
# Run: 69, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 77.01449275362319, max: 172)
#
# Run: 70, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 77.41428571428571, max: 172)
#
# Run: 71, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 78.02816901408451, max: 172)
#
# Run: 72, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 78.84722222222223, max: 172)
#
# Run: 73, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 79.53424657534246, max: 172)
#
# Run: 74, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 80.10810810810811, max: 172)
#
# Run: 75, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 80.49333333333334, max: 172)
#
# Run: 76, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 81.3157894736842, max: 172)
#
# Run: 77, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 81.8961038961039, max: 172)
#
# Run: 78, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 82.65384615384616, max: 172)
#
# Run: 79, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 83.17721518987342, max: 172)
#
# Run: 80, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 83.4875, max: 172)
#
# Run: 81, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 84.04938271604938, max: 172)
#
# Run: 82, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 84.2560975609756, max: 172)
#
# Run: 83, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 84.60240963855422, max: 172)
#
# Run: 84, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 85.19047619047619, max: 172)
#
# Run: 85, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 85.41176470588235, max: 172)
#
# Run: 86, exploration: 0.01, score: 272
# Scores: (min: 9, avg: 87.5813953488372, max: 272)
#
# Run: 87, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 88.22988505747126, max: 272)
#
# Run: 88, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 88.89772727272727, max: 272)
# Run: 89, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 89.49438202247191, max: 272)
#
# Run: 90, exploration: 0.01, score: 102
# Scores: (min: 9, avg: 89.63333333333334, max: 272)
#
# Run: 91, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 89.78021978021978, max: 272)
#
# Run: 92, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 89.55434782608695, max: 272)
#
# Run: 93, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 89.21505376344086, max: 272)
#
# Run: 94, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 89.81914893617021, max: 272)
#
# Run: 95, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 89.6842105263158, max: 272)
#
# Run: 96, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 90.36458333333333, max: 272)
#
# Run: 97, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 90.51546391752578, max: 272)
#
# Run: 98, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 90.93877551020408, max: 272)
#
# Run: 99, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 91.41414141414141, max: 272)
#
# Run: 100, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 91.78, max: 272)
#
# Run: 101, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 92.65, max: 272)
#
# Run: 102, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 93.53, max: 272)
#
# Run: 103, exploration: 0.01, score: 88
# Scores: (min: 9, avg: 94.31, max: 272)
#
# Run: 104, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 95.41, max: 272)
#
# Run: 105, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 96.23, max: 272)
#
# Run: 106, exploration: 0.01, score: 297
# Scores: (min: 9, avg: 98.85, max: 297)
#
# Run: 107, exploration: 0.01, score: 90
# Scores: (min: 9, avg: 99.42, max: 297)
#
# Run: 108, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 100.48, max: 297)
#
# Run: 109, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 101.47, max: 297)
#
# Run: 110, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 102.3, max: 297)
#
# Run: 111, exploration: 0.01, score: 88
# Scores: (min: 9, avg: 103.04, max: 297)
#
# Run: 112, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 103.77, max: 297)
#
# Run: 113, exploration: 0.01, score: 192
# Scores: (min: 9, avg: 105.47, max: 297)
#
# Run: 114, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 107.33, max: 297)
#
# Run: 115, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 108.14, max: 297)
#
# Run: 116, exploration: 0.01, score: 83
# Scores: (min: 9, avg: 108.72, max: 297)
#
# Run: 117, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 109.32, max: 297)
#
# Run: 118, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 110.38, max: 297)
#
# Run: 119, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 111.15, max: 297)
#
# Run: 120, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 111.65, max: 297)
#
# Run: 121, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 111.64, max: 297)
#
# Run: 122, exploration: 0.01, score: 104
# Scores: (min: 15, avg: 112.59, max: 297)
#
# Run: 123, exploration: 0.01, score: 60
# Scores: (min: 15, avg: 113.04, max: 297)
#
# Run: 124, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 113.01, max: 297)
#
# Run: 125, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 113.77, max: 297)
#
# Run: 126, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 114.46, max: 297)
#
# Run: 127, exploration: 0.01, score: 99
# Scores: (min: 12, avg: 115.16, max: 297)
#
# Run: 128, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 115.69, max: 297)
#
# Run: 129, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 116.61, max: 297)
#
# Run: 130, exploration: 0.01, score: 104
# Scores: (min: 12, avg: 117.05, max: 297)
#
# Run: 131, exploration: 0.01, score: 55
# Scores: (min: 12, avg: 117.41, max: 297)
#
# Run: 132, exploration: 0.01, score: 101
# Scores: (min: 12, avg: 118.05, max: 297)
#
# Run: 133, exploration: 0.01, score: 112
# Scores: (min: 12, avg: 118.68, max: 297)
#
# Run: 134, exploration: 0.01, score: 59
# Scores: (min: 12, avg: 118.94, max: 297)
#
# Run: 135, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 119.78, max: 297)
#
# Run: 136, exploration: 0.01, score: 99
# Scores: (min: 12, avg: 120.11, max: 297)
#
# Run: 137, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 120.12, max: 297)
#
# Run: 138, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 120.26, max: 297)
#
# Run: 139, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 120.12, max: 297)
#
# Run: 140, exploration: 0.01, score: 129
# Scores: (min: 12, avg: 119.74, max: 297)
#
# Run: 141, exploration: 0.01, score: 60
# Scores: (min: 12, avg: 118.97, max: 297)
#
# Run: 142, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 118.73, max: 297)
#
# Run: 143, exploration: 0.01, score: 101
# Scores: (min: 12, avg: 118.34, max: 297)
#
# Run: 144, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 118.06, max: 297)
#
# Run: 145, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 118.4, max: 297)
#
# Run: 146, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 118.39, max: 297)
#
# Run: 147, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 118.34, max: 297)
#
# Run: 148, exploration: 0.01, score: 246
# Scores: (min: 12, avg: 119.28, max: 297)
#
# Run: 149, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 119.47, max: 297)
#
# Run: 150, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 119.49, max: 297)
#
# Run: 151, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 119.54, max: 297)
#
# Run: 152, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 118.28, max: 297)
#
# Run: 153, exploration: 0.01, score: 223
# Scores: (min: 12, avg: 119.36, max: 297)
#
# Run: 154, exploration: 0.01, score: 149
# Scores: (min: 12, avg: 119.59, max: 297)
#
# Run: 155, exploration: 0.01, score: 196
# Scores: (min: 12, avg: 120.13, max: 297)
#
# Run: 156, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 119.96, max: 297)
#
# Run: 157, exploration: 0.01, score: 179
# Scores: (min: 12, avg: 120.33, max: 297)
#
# Run: 158, exploration: 0.01, score: 149
# Scores: (min: 12, avg: 120.56, max: 297)
#
# Run: 159, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 119.79, max: 297)
#
# Run: 160, exploration: 0.01, score: 174
# Scores: (min: 12, avg: 120.33, max: 297)
#
# Run: 161, exploration: 0.01, score: 85
# Scores: (min: 12, avg: 119.92, max: 297)
#
# Run: 162, exploration: 0.01, score: 98
# Scores: (min: 12, avg: 119.65, max: 297)
#
# Run: 163, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 119.57, max: 297)
#
# Run: 164, exploration: 0.01, score: 271
# Scores: (min: 12, avg: 120.95, max: 297)
#
# Run: 165, exploration: 0.01, score: 92
# Scores: (min: 12, avg: 120.4, max: 297)
#
# Run: 166, exploration: 0.01, score: 106
# Scores: (min: 12, avg: 120.37, max: 297)
#
# Run: 167, exploration: 0.01, score: 108
# Scores: (min: 12, avg: 120.16, max: 297)
#
# Run: 168, exploration: 0.01, score: 151
# Scores: (min: 12, avg: 120.6, max: 297)
#
# Run: 169, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 119.41, max: 297)
#
# Run: 170, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 118.45, max: 297)
#
# Run: 171, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 117.35, max: 297)
#
# Run: 172, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 117.87, max: 297)
#
# Run: 173, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 117.13, max: 297)
#
# Run: 174, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 117.29, max: 297)
#
# Run: 175, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 118.07, max: 297)
#
# Run: 176, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 117.07, max: 297)
#
# Run: 177, exploration: 0.01, score: 292
# Scores: (min: 9, avg: 118.73, max: 297)
#
# Run: 178, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 119.38, max: 297)
#
# Run: 179, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 119.59, max: 297)
#
# Run: 180, exploration: 0.01, score: 336
# Scores: (min: 9, avg: 121.87, max: 336)
#
# Run: 181, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 122, max: 336)
#
# Run: 182, exploration: 0.01, score: 409
# Scores: (min: 9, avg: 125.08, max: 409)
#
# Run: 183, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 125.57, max: 409)
#
# Run: 184, exploration: 0.01, score: 357
# Scores: (min: 9, avg: 127.8, max: 409)
#
# Run: 185, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 128.65, max: 409)
#
# Run: 186, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 127.78, max: 409)
#
# Run: 187, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 126.92, max: 409)
#
# Run: 188, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 125.91, max: 409)
# Run: 189, exploration: 0.01, score: 220
# Scores: (min: 9, avg: 126.69, max: 409)
#
# Run: 190, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 128.03, max: 409)
#
# Run: 191, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 128.03, max: 409)
#
# Run: 192, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 129.21, max: 409)
#
# Run: 193, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 130.22, max: 409)
#
# Run: 194, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 129.15, max: 409)
#
# Run: 195, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 128.91, max: 409)
#
# Run: 196, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 127.59, max: 409)
#
# Run: 197, exploration: 0.01, score: 253
# Scores: (min: 9, avg: 129.07, max: 409)
#
# Run: 198, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 132.75, max: 500)
#
# Run: 199, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 133.49, max: 500)
#
# Run: 200, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 137.21, max: 500)
#
# Run: 201, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 137.63, max: 500)
#
# Run: 202, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 141.33, max: 500)
#
# Run: 203, exploration: 0.01, score: 258
# Scores: (min: 9, avg: 143.03, max: 500)
#
# Run: 204, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 146.73, max: 500)
#
# Run: 205, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 150.78, max: 500)
#
# Run: 206, exploration: 0.01, score: 462
# Scores: (min: 9, avg: 152.43, max: 500)
#
# Run: 207, exploration: 0.01, score: 292
# Scores: (min: 9, avg: 154.45, max: 500)
#
# Run: 208, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 154.54, max: 500)
#
# Run: 209, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 154.65, max: 500)
#
# Run: 210, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 155.12, max: 500)
#
# Run: 211, exploration: 0.01, score: 263
# Scores: (min: 9, avg: 156.87, max: 500)
#
# Run: 212, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 157.91, max: 500)
#
# Run: 213, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 158.07, max: 500)
#
# Run: 214, exploration: 0.01, score: 313
# Scores: (min: 9, avg: 159.17, max: 500)
#
# Run: 215, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 160.16, max: 500)
#
# Run: 216, exploration: 0.01, score: 287
# Scores: (min: 9, avg: 162.2, max: 500)
#
# Run: 217, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 162.5, max: 500)
#
# Run: 218, exploration: 0.01, score: 273
# Scores: (min: 9, avg: 163.92, max: 500)
#
# Run: 219, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 164.17, max: 500)
#
# Run: 220, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 164.77, max: 500)
#
# Run: 221, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 165.65, max: 500)
#
# Run: 222, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 165.87, max: 500)
#
# Run: 223, exploration: 0.01, score: 102
# Scores: (min: 9, avg: 166.29, max: 500)
#
# Run: 224, exploration: 0.01, score: 82
# Scores: (min: 9, avg: 166.99, max: 500)
#
# Run: 225, exploration: 0.01, score: 245
# Scores: (min: 9, avg: 168.37, max: 500)
#
# Run: 226, exploration: 0.01, score: 86
# Scores: (min: 9, avg: 168.27, max: 500)
#
# Run: 227, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 168.68, max: 500)
#
# Run: 228, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 168.77, max: 500)
#
# Run: 229, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 168.74, max: 500)
#
# Run: 230, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 169.15, max: 500)
#
# Run: 231, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 169.96, max: 500)
#
# Run: 232, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 170.5, max: 500)
#
# Run: 233, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 171.06, max: 500)
#
# Run: 234, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 172.55, max: 500)
#
# Run: 235, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 172.85, max: 500)
#
# Run: 236, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 173.82, max: 500)
#
# Run: 237, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 174.11, max: 500)
#
# Run: 238, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 174.11, max: 500)
#
# Run: 239, exploration: 0.01, score: 96
# Scores: (min: 9, avg: 173.49, max: 500)
#
# Run: 240, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 173.48, max: 500)
#
# Run: 241, exploration: 0.01, score: 392
# Scores: (min: 9, avg: 176.8, max: 500)
#
# Run: 242, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 177.34, max: 500)
#
# Run: 243, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 177.91, max: 500)
#
# Run: 244, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 177.98, max: 500)
#
# Run: 245, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 178.33, max: 500)
#
# Run: 246, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 178.47, max: 500)
#
# Run: 247, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 182.21, max: 500)
#
# Run: 248, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 181.43, max: 500)
#
# Run: 249, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 181.98, max: 500)
#
# Run: 250, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 182.35, max: 500)
#
# Run: 251, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 182.74, max: 500)
#
# Run: 252, exploration: 0.01, score: 308
# Scores: (min: 9, avg: 185.7, max: 500)
#
# Run: 253, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 185.38, max: 500)
#
# Run: 254, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 185.84, max: 500)
#
# Run: 255, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 184.92, max: 500)
#
# Run: 256, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 185.64, max: 500)
#
# Run: 257, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 184.84, max: 500)
#
# Run: 258, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 184.44, max: 500)
#
# Run: 259, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 185.35, max: 500)
#
# Run: 260, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 184.96, max: 500)
#
# Run: 261, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 186.23, max: 500)
#
# Run: 262, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 186.82, max: 500)
#
# Run: 263, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 186.92, max: 500)
#
# Run: 264, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 185.43, max: 500)
#
# Run: 265, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 185.58, max: 500)
#
# Run: 266, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 185.62, max: 500)
#
# Run: 267, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 185.21, max: 500)
#
# Run: 268, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 184.68, max: 500)
#
# Run: 269, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 185.48, max: 500)
#
# Run: 270, exploration: 0.01, score: 106
# Scores: (min: 11, avg: 186.45, max: 500)
#
# Run: 271, exploration: 0.01, score: 184
# Scores: (min: 23, avg: 188.18, max: 500)
#
# Run: 272, exploration: 0.01, score: 119
# Scores: (min: 23, avg: 187.48, max: 500)
#
# Run: 273, exploration: 0.01, score: 255
# Scores: (min: 23, avg: 189.48, max: 500)
#
# Run: 274, exploration: 0.01, score: 101
# Scores: (min: 23, avg: 189.11, max: 500)
#
# Run: 275, exploration: 0.01, score: 244
# Scores: (min: 23, avg: 189.68, max: 500)
#
# Run: 276, exploration: 0.01, score: 192
# Scores: (min: 23, avg: 191.17, max: 500)
#
# Run: 277, exploration: 0.01, score: 104
# Scores: (min: 23, avg: 189.29, max: 500)
#
# Run: 278, exploration: 0.01, score: 118
# Scores: (min: 23, avg: 188.41, max: 500)
#
# Run: 279, exploration: 0.01, score: 29
# Scores: (min: 23, avg: 187.25, max: 500)
#
# Run: 280, exploration: 0.01, score: 162
# Scores: (min: 23, avg: 185.51, max: 500)
#
# Run: 281, exploration: 0.01, score: 332
# Scores: (min: 23, avg: 187.41, max: 500)
#
# Run: 282, exploration: 0.01, score: 348
# Scores: (min: 23, avg: 186.8, max: 500)
#
# Run: 283, exploration: 0.01, score: 172
# Scores: (min: 23, avg: 186.9, max: 500)
#
# Run: 284, exploration: 0.01, score: 168
# Scores: (min: 23, avg: 185.01, max: 500)
#
# Run: 285, exploration: 0.01, score: 146
# Scores: (min: 23, avg: 184.58, max: 500)
#
# Run: 286, exploration: 0.01, score: 500
# Scores: (min: 23, avg: 187.73, max: 500)
#
# Run: 287, exploration: 0.01, score: 199
# Scores: (min: 23, avg: 189.14, max: 500)
#
# Run: 288, exploration: 0.01, score: 113
# Scores: (min: 23, avg: 189.81, max: 500)
#
# Run: 289, exploration: 0.01, score: 141
# Scores: (min: 23, avg: 189.02, max: 500)
#
# Run: 290, exploration: 0.01, score: 145
# Scores: (min: 23, avg: 188.11, max: 500)
# Run: 291, exploration: 0.01, score: 134
# Scores: (min: 23, avg: 188.42, max: 500)
#
# Run: 292, exploration: 0.01, score: 156
# Scores: (min: 23, avg: 188.11, max: 500)
#
# Run: 293, exploration: 0.01, score: 249
# Scores: (min: 23, avg: 189.01, max: 500)
#
# Run: 294, exploration: 0.01, score: 110
# Scores: (min: 23, avg: 189.72, max: 500)
#
# Run: 295, exploration: 0.01, score: 88
# Scores: (min: 23, avg: 190.07, max: 500)
#
# Run: 296, exploration: 0.01, score: 399
# Scores: (min: 29, avg: 193.83, max: 500)
#
# Run: 297, exploration: 0.01, score: 174
# Scores: (min: 29, avg: 193.04, max: 500)
#
# Run: 298, exploration: 0.01, score: 145
# Scores: (min: 29, avg: 189.49, max: 500)
#
# Run: 299, exploration: 0.01, score: 123
# Scores: (min: 29, avg: 188.6, max: 500)
#
# Run: 300, exploration: 0.01, score: 165
# Scores: (min: 29, avg: 185.25, max: 500)
#
# Run: 301, exploration: 0.01, score: 316
# Scores: (min: 29, avg: 186.96, max: 500)
#
# Run: 302, exploration: 0.01, score: 143
# Scores: (min: 29, avg: 183.39, max: 500)
#
# Run: 303, exploration: 0.01, score: 325
# Scores: (min: 29, avg: 184.06, max: 500)
#
# Run: 304, exploration: 0.01, score: 140
# Scores: (min: 29, avg: 180.46, max: 500)
#
# Run: 305, exploration: 0.01, score: 182
# Scores: (min: 29, avg: 177.28, max: 500)
#
# Run: 306, exploration: 0.01, score: 129
# Scores: (min: 29, avg: 173.95, max: 500)
#
# Run: 307, exploration: 0.01, score: 158
# Scores: (min: 29, avg: 172.61, max: 500)
#
# Run: 308, exploration: 0.01, score: 237
# Scores: (min: 29, avg: 173.72, max: 500)
#
# Run: 309, exploration: 0.01, score: 112
# Scores: (min: 29, avg: 173.64, max: 500)
#
# Run: 310, exploration: 0.01, score: 128
# Scores: (min: 29, avg: 173.5, max: 500)
#
# Run: 311, exploration: 0.01, score: 154
# Scores: (min: 29, avg: 172.41, max: 500)
#
# Run: 312, exploration: 0.01, score: 394
# Scores: (min: 29, avg: 174.3, max: 500)
#
# Run: 313, exploration: 0.01, score: 251
# Scores: (min: 29, avg: 174.73, max: 500)
#
# Run: 314, exploration: 0.01, score: 119
# Scores: (min: 29, avg: 172.79, max: 500)
#
# Run: 315, exploration: 0.01, score: 162
# Scores: (min: 29, avg: 172.43, max: 500)
#
# Run: 316, exploration: 0.01, score: 309
# Scores: (min: 29, avg: 172.65, max: 500)
#
# Run: 317, exploration: 0.01, score: 216
# Scores: (min: 29, avg: 173.56, max: 500)
#
# Run: 318, exploration: 0.01, score: 180
# Scores: (min: 29, avg: 172.63, max: 500)
#
# Run: 319, exploration: 0.01, score: 377
# Scores: (min: 29, avg: 175.16, max: 500)
#
# Run: 320, exploration: 0.01, score: 116
# Scores: (min: 29, avg: 175.08, max: 500)
#
# Run: 321, exploration: 0.01, score: 124
# Scores: (min: 29, avg: 175.05, max: 500)
#
# Run: 322, exploration: 0.01, score: 124
# Scores: (min: 29, avg: 175.03, max: 500)
#
# Run: 323, exploration: 0.01, score: 275
# Scores: (min: 29, avg: 176.76, max: 500)
#
# Run: 324, exploration: 0.01, score: 310
# Scores: (min: 29, avg: 179.04, max: 500)
#
# Run: 325, exploration: 0.01, score: 338
# Scores: (min: 29, avg: 179.97, max: 500)
#
# Run: 326, exploration: 0.01, score: 143
# Scores: (min: 29, avg: 180.54, max: 500)
#
# Run: 327, exploration: 0.01, score: 158
# Scores: (min: 29, avg: 180.72, max: 500)
#
# Run: 328, exploration: 0.01, score: 166
# Scores: (min: 29, avg: 181.33, max: 500)
#
# Run: 329, exploration: 0.01, score: 154
# Scores: (min: 29, avg: 181.76, max: 500)
#
# Run: 330, exploration: 0.01, score: 249
# Scores: (min: 29, avg: 182.8, max: 500)
#
# Run: 331, exploration: 0.01, score: 28
# Scores: (min: 28, avg: 181.72, max: 500)
#
# Run: 332, exploration: 0.01, score: 309
# Scores: (min: 28, avg: 183.26, max: 500)
#
# Run: 333, exploration: 0.01, score: 151
# Scores: (min: 28, avg: 183.09, max: 500)
#
# Run: 334, exploration: 0.01, score: 60
# Scores: (min: 28, avg: 181.61, max: 500)
#
# Run: 335, exploration: 0.01, score: 107
# Scores: (min: 28, avg: 180.98, max: 500)
#
# Run: 336, exploration: 0.01, score: 357
# Scores: (min: 28, avg: 182.59, max: 500)
#
# Run: 337, exploration: 0.01, score: 154
# Scores: (min: 28, avg: 182.7, max: 500)
#
# Run: 338, exploration: 0.01, score: 265
# Scores: (min: 28, avg: 184.32, max: 500)
#
# Run: 339, exploration: 0.01, score: 202
# Scores: (min: 28, avg: 185.38, max: 500)
#
# Run: 340, exploration: 0.01, score: 56
# Scores: (min: 28, avg: 184.66, max: 500)
#
# Run: 341, exploration: 0.01, score: 25
# Scores: (min: 25, avg: 180.99, max: 500)
#
# Run: 342, exploration: 0.01, score: 111
# Scores: (min: 25, avg: 180.21, max: 500)
#
# Run: 343, exploration: 0.01, score: 28
# Scores: (min: 25, avg: 178.91, max: 500)
#
# Run: 344, exploration: 0.01, score: 31
# Scores: (min: 25, avg: 177.94, max: 500)
#
# Run: 345, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 175.98, max: 500)
#
# Run: 346, exploration: 0.01, score: 44
# Scores: (min: 12, avg: 175.02, max: 500)
#
# Run: 347, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 170.13, max: 500)
#
# Run: 348, exploration: 0.01, score: 59
# Scores: (min: 11, avg: 169.04, max: 500)
#
# Run: 349, exploration: 0.01, score: 194
# Scores: (min: 11, avg: 169.03, max: 500)
#
# Run: 350, exploration: 0.01, score: 414
# Scores: (min: 11, avg: 171.52, max: 500)
#
# Run: 351, exploration: 0.01, score: 252
# Scores: (min: 11, avg: 172.31, max: 500)
#
# Run: 352, exploration: 0.01, score: 223
# Scores: (min: 11, avg: 171.46, max: 500)
#
# Run: 353, exploration: 0.01, score: 162
# Scores: (min: 11, avg: 171.17, max: 500)
#
# Run: 354, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 170.66, max: 500)
#
# Run: 355, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 170.85, max: 500)
#
# Run: 356, exploration: 0.01, score: 220
# Scores: (min: 11, avg: 171.26, max: 500)
#
# Run: 357, exploration: 0.01, score: 110
# Scores: (min: 11, avg: 171.37, max: 500)
#
# Run: 358, exploration: 0.01, score: 179
# Scores: (min: 11, avg: 172.07, max: 500)
#
# Run: 359, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 172.37, max: 500)
#
# Run: 360, exploration: 0.01, score: 68
# Scores: (min: 11, avg: 171.7, max: 500)
#
# Run: 361, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 169.96, max: 500)
#
# Run: 362, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 168.52, max: 500)
#
# Run: 363, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 167.53, max: 500)
#
# Run: 364, exploration: 0.01, score: 65
# Scores: (min: 11, avg: 166.96, max: 500)
#
# Run: 365, exploration: 0.01, score: 359
# Scores: (min: 11, avg: 169.48, max: 500)
#
# Run: 366, exploration: 0.01, score: 63
# Scores: (min: 11, avg: 169.01, max: 500)
#
# Run: 367, exploration: 0.01, score: 468
# Scores: (min: 11, avg: 173.02, max: 500)
#
# Run: 368, exploration: 0.01, score: 276
# Scores: (min: 11, avg: 174.8, max: 500)
#
# Run: 369, exploration: 0.01, score: 89
# Scores: (min: 11, avg: 174.61, max: 500)
#
# Run: 370, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 174.52, max: 500)
#
# Run: 371, exploration: 0.01, score: 63
# Scores: (min: 11, avg: 173.31, max: 500)
#
# Run: 372, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 173.77, max: 500)
#
# Run: 373, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 171.58, max: 500)
#
# Run: 374, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 171.79, max: 500)
#
# Run: 375, exploration: 0.01, score: 83
# Scores: (min: 11, avg: 170.18, max: 500)
#
# Run: 376, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 169.39, max: 500)
#
# Run: 377, exploration: 0.01, score: 332
# Scores: (min: 11, avg: 171.67, max: 500)
#
# Run: 378, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 172.1, max: 500)
#
# Run: 379, exploration: 0.01, score: 386
# Scores: (min: 11, avg: 175.67, max: 500)
#
# Run: 380, exploration: 0.01, score: 302
# Scores: (min: 11, avg: 177.07, max: 500)
#
# Run: 381, exploration: 0.01, score: 68
# Scores: (min: 11, avg: 174.43, max: 500)
#
# Run: 382, exploration: 0.01, score: 24
# Scores: (min: 11, avg: 171.19, max: 500)
#
# Run: 383, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 169.63, max: 500)
#
# Run: 384, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 169.23, max: 500)
#
# Run: 385, exploration: 0.01, score: 235
# Scores: (min: 11, avg: 170.12, max: 500)
#
# Run: 386, exploration: 0.01, score: 361
# Scores: (min: 11, avg: 168.73, max: 468)
#
# Run: 387, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 171.74, max: 500)
#
# Run: 388, exploration: 0.01, score: 227
# Scores: (min: 11, avg: 172.88, max: 500)
#
# Run: 389, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 172.7, max: 500)
#
# Run: 390, exploration: 0.01, score: 129
# Scores: (min: 11, avg: 172.54, max: 500)
#
# Run: 391, exploration: 0.01, score: 206
# Scores: (min: 11, avg: 173.26, max: 500)
# Run: 392, exploration: 0.01, score: 224
# Scores: (min: 11, avg: 173.94, max: 500)
#
# Run: 393, exploration: 0.01, score: 95
# Scores: (min: 11, avg: 172.4, max: 500)
#
# Run: 394, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 176.3, max: 500)
#
# Run: 395, exploration: 0.01, score: 138
# Scores: (min: 11, avg: 176.8, max: 500)
#
# Run: 396, exploration: 0.01, score: 88
# Scores: (min: 11, avg: 173.69, max: 500)
#
# Run: 397, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 173.42, max: 500)
#
# Run: 398, exploration: 0.01, score: 169
# Scores: (min: 11, avg: 173.66, max: 500)
#
# Run: 399, exploration: 0.01, score: 206
# Scores: (min: 11, avg: 174.49, max: 500)
#
# Run: 400, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 177.84, max: 500)
#
# Run: 401, exploration: 0.01, score: 110
# Scores: (min: 11, avg: 175.78, max: 500)
#
# Run: 402, exploration: 0.01, score: 339
# Scores: (min: 11, avg: 177.74, max: 500)
#
# Run: 403, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 175.88, max: 500)
#
# Run: 404, exploration: 0.01, score: 214
# Scores: (min: 11, avg: 176.62, max: 500)
#
# Run: 405, exploration: 0.01, score: 86
# Scores: (min: 11, avg: 175.66, max: 500)
#
# Run: 406, exploration: 0.01, score: 176
# Scores: (min: 11, avg: 176.13, max: 500)
#
# Run: 407, exploration: 0.01, score: 310
# Scores: (min: 11, avg: 177.65, max: 500)
#
# Run: 408, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 180.28, max: 500)
#
# Run: 409, exploration: 0.01, score: 315
# Scores: (min: 11, avg: 182.31, max: 500)
#
# Run: 410, exploration: 0.01, score: 192
# Scores: (min: 11, avg: 182.95, max: 500)
#
# Run: 411, exploration: 0.01, score: 475
# Scores: (min: 11, avg: 186.16, max: 500)
#
# Run: 412, exploration: 0.01, score: 57
# Scores: (min: 11, avg: 182.79, max: 500)
#
# Run: 413, exploration: 0.01, score: 177
# Scores: (min: 11, avg: 182.05, max: 500)
#
# Run: 414, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 182.4, max: 500)
#
# Run: 415, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 182.14, max: 500)
#
# Run: 416, exploration: 0.01, score: 138
# Scores: (min: 11, avg: 180.43, max: 500)
#
# Run: 417, exploration: 0.01, score: 222
# Scores: (min: 11, avg: 180.49, max: 500)
#
# Run: 418, exploration: 0.01, score: 61
# Scores: (min: 11, avg: 179.3, max: 500)
#
# Run: 419, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 176.77, max: 500)
#
# Run: 420, exploration: 0.01, score: 393
# Scores: (min: 11, avg: 179.54, max: 500)
#
# Run: 421, exploration: 0.01, score: 188
# Scores: (min: 11, avg: 180.18, max: 500)
#
# Run: 422, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 183.94, max: 500)
#
# Run: 423, exploration: 0.01, score: 434
# Scores: (min: 11, avg: 185.53, max: 500)
#
# Run: 424, exploration: 0.01, score: 108
# Scores: (min: 11, avg: 183.51, max: 500)
#
# Run: 425, exploration: 0.01, score: 43
# Scores: (min: 11, avg: 180.56, max: 500)
#
# Run: 426, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 180.52, max: 500)
#
# Run: 427, exploration: 0.01, score: 251
# Scores: (min: 11, avg: 181.45, max: 500)
#
# Run: 428, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 180.92, max: 500)
#
# Run: 429, exploration: 0.01, score: 302
# Scores: (min: 11, avg: 182.4, max: 500)
#
# Run: 430, exploration: 0.01, score: 421
# Scores: (min: 11, avg: 184.12, max: 500)
#
# Run: 431, exploration: 0.01, score: 317
# Scores: (min: 11, avg: 187.01, max: 500)
#
# Run: 432, exploration: 0.01, score: 273
# Scores: (min: 11, avg: 186.65, max: 500)
#
# Run: 433, exploration: 0.01, score: 323
# Scores: (min: 11, avg: 188.37, max: 500)
#
# Run: 434, exploration: 0.01, score: 291
# Scores: (min: 11, avg: 190.68, max: 500)
#
# Run: 435, exploration: 0.01, score: 257
# Scores: (min: 11, avg: 192.18, max: 500)
#
# Run: 436, exploration: 0.01, score: 227
# Scores: (min: 11, avg: 190.88, max: 500)
#
# Run: 437, exploration: 0.01, score: 213
# Scores: (min: 11, avg: 191.47, max: 500)
#
# Run: 438, exploration: 0.01, score: 495
# Scores: (min: 11, avg: 193.77, max: 500)
#
# Run: 439, exploration: 0.01, score: 316
# Scores: (min: 11, avg: 194.91, max: 500)
#
# Run: 440, exploration: 0.01, score: 197
# Scores: (min: 11, avg: 196.32, max: 500)
#
# Solved in 340 runs, 440 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

# Experiment 1
GAMMA = 0.99 # changed the decay rate (discount factor) of past observations from 0.95 to 0.99  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 9
# Scores: (min: 9, avg: 9, max: 9)
#
# Run: 2, exploration: 0.9655206468094844, score: 18
# Scores: (min: 9, avg: 13.5, max: 18)
#
# Run: 3, exploration: 0.9091562615825302, score: 13
# Scores: (min: 9, avg: 13.333333333333334, max: 18)
#
# Run: 4, exploration: 0.7822236754458713, score: 31
# Scores: (min: 9, avg: 17.75, max: 31)
#
# Run: 5, exploration: 0.736559652908221, score: 13
# Scores: (min: 9, avg: 16.8, max: 31)
#
# Run: 6, exploration: 0.6832098777212641, score: 16
# Scores: (min: 9, avg: 16.666666666666668, max: 31)
#
# Run: 7, exploration: 0.6401093727576664, score: 14
# Scores: (min: 9, avg: 16.285714285714285, max: 31)
#
# Run: 8, exploration: 0.6027415843082742, score: 13
# Scores: (min: 9, avg: 15.875, max: 31)
#
# Run: 9, exploration: 0.5590843898207511, score: 16
# Scores: (min: 9, avg: 15.88888888888889, max: 31)
#
# Run: 10, exploration: 0.5211953074858876, score: 15
# Scores: (min: 9, avg: 15.8, max: 31)
#
# Run: 11, exploration: 0.4932355662165453, score: 12
# Scores: (min: 9, avg: 15.454545454545455, max: 31)
#
# Run: 12, exploration: 0.4738479773082268, score: 9
# Scores: (min: 9, avg: 14.916666666666666, max: 31)
#
# Run: 13, exploration: 0.446186062443672, score: 13
# Scores: (min: 9, avg: 14.76923076923077, max: 31)
#
# Run: 14, exploration: 0.42013897252428334, score: 13
# Scores: (min: 9, avg: 14.642857142857142, max: 31)
#
# Run: 15, exploration: 0.3976004408064698, score: 12
# Scores: (min: 9, avg: 14.466666666666667, max: 31)
#
# Run: 16, exploration: 0.37251769488706843, score: 14
# Scores: (min: 9, avg: 14.4375, max: 31)
#
# Run: 17, exploration: 0.35253382661792404, score: 12
# Scores: (min: 9, avg: 14.294117647058824, max: 31)
#
# Run: 18, exploration: 0.33362200135903064, score: 12
# Scores: (min: 9, avg: 14.166666666666666, max: 31)
#
# Run: 19, exploration: 0.32050833588933575, score: 9
# Scores: (min: 9, avg: 13.894736842105264, max: 31)
#
# Run: 20, exploration: 0.3063705780533402, score: 10
# Scores: (min: 9, avg: 13.7, max: 31)
#
# Run: 21, exploration: 0.2943280830920294, score: 9
# Scores: (min: 9, avg: 13.476190476190476, max: 31)
#
# Run: 22, exploration: 0.2799384215094006, score: 11
# Scores: (min: 9, avg: 13.363636363636363, max: 31)
#
# Run: 23, exploration: 0.2649210072611673, score: 12
# Scores: (min: 9, avg: 13.304347826086957, max: 31)
#
# Run: 24, exploration: 0.25450776877280124, score: 9
# Scores: (min: 9, avg: 13.125, max: 31)
#
# Run: 25, exploration: 0.24450384299593592, score: 9
# Scores: (min: 9, avg: 12.96, max: 31)
#
# Run: 26, exploration: 0.23489314109365644, score: 9
# Scores: (min: 9, avg: 12.807692307692308, max: 31)
#
# Run: 27, exploration: 0.22229219984074702, score: 12
# Scores: (min: 9, avg: 12.777777777777779, max: 31)
#
# Run: 28, exploration: 0.21036724137609603, score: 12
# Scores: (min: 9, avg: 12.75, max: 31)
#
# Run: 29, exploration: 0.2000824143909432, score: 11
# Scores: (min: 9, avg: 12.689655172413794, max: 31)
#
# Run: 30, exploration: 0.1912566947289212, score: 10
# Scores: (min: 9, avg: 12.6, max: 31)
#
# Run: 31, exploration: 0.182820281282489, score: 10
# Scores: (min: 9, avg: 12.516129032258064, max: 31)
#
# Run: 32, exploration: 0.17388222158237718, score: 11
# Scores: (min: 9, avg: 12.46875, max: 31)
#
# Run: 33, exploration: 0.16538114245489302, score: 11
# Scores: (min: 9, avg: 12.424242424242424, max: 31)
#
# Run: 34, exploration: 0.1557266555690826, score: 13
# Scores: (min: 9, avg: 12.441176470588236, max: 31)
#
# Run: 35, exploration: 0.14960551470448571, score: 9
# Scores: (min: 9, avg: 12.342857142857143, max: 31)
#
# Run: 36, exploration: 0.14229132060898236, score: 11
# Scores: (min: 9, avg: 12.305555555555555, max: 31)
#
# Run: 37, exploration: 0.13669828187021155, score: 9
# Scores: (min: 9, avg: 12.216216216216216, max: 31)
#
# Run: 38, exploration: 0.12936504510050365, score: 12
# Scores: (min: 9, avg: 12.210526315789474, max: 31)
#
# Run: 39, exploration: 0.12365869841532712, score: 10
# Scores: (min: 9, avg: 12.153846153846153, max: 31)
#
# Run: 40, exploration: 0.11939502647758558, score: 8
# Scores: (min: 8, avg: 12.05, max: 31)
#
# Run: 41, exploration: 0.11412846151764894, score: 10
# Scores: (min: 8, avg: 12, max: 31)
#
# Run: 42, exploration: 0.10964241905397228, score: 9
# Scores: (min: 8, avg: 11.928571428571429, max: 31)
#
# Run: 43, exploration: 0.1042820154910064, score: 11
# Scores: (min: 8, avg: 11.906976744186046, max: 31)
#
# Run: 44, exploration: 0.09868776295209031, score: 12
# Scores: (min: 8, avg: 11.909090909090908, max: 31)
#
# Run: 45, exploration: 0.0943346041173244, score: 10
# Scores: (min: 8, avg: 11.866666666666667, max: 31)
#
# Run: 46, exploration: 0.0906265979439563, score: 9
# Scores: (min: 8, avg: 11.804347826086957, max: 31)
#
# Run: 47, exploration: 0.08706434220766679, score: 9
# Scores: (min: 8, avg: 11.74468085106383, max: 31)
#
# Run: 48, exploration: 0.0832238973628649, score: 10
# Scores: (min: 8, avg: 11.708333333333334, max: 31)
#
# Run: 49, exploration: 0.07955285615946175, score: 10
# Scores: (min: 8, avg: 11.673469387755102, max: 31)
#
# Run: 50, exploration: 0.07642587550895225, score: 9
# Scores: (min: 8, avg: 11.62, max: 31)
#
# Run: 51, exploration: 0.07305469791585968, score: 10
# Scores: (min: 8, avg: 11.588235294117647, max: 31)
#
# Run: 52, exploration: 0.06948306326589085, score: 11
# Scores: (min: 8, avg: 11.576923076923077, max: 31)
#
# Run: 53, exploration: 0.06641813604822402, score: 10
# Scores: (min: 8, avg: 11.547169811320755, max: 31)
#
# Run: 54, exploration: 0.06380744126877576, score: 9
# Scores: (min: 8, avg: 11.5, max: 31)
#
# Run: 55, exploration: 0.06129936495526111, score: 9
# Scores: (min: 8, avg: 11.454545454545455, max: 31)
#
# Run: 56, exploration: 0.05918580250061433, score: 8
# Scores: (min: 8, avg: 11.392857142857142, max: 31)
#
# Run: 57, exploration: 0.056292216338080694, score: 11
# Scores: (min: 8, avg: 11.385964912280702, max: 31)
#
# Run: 58, exploration: 0.05407954064343768, score: 9
# Scores: (min: 8, avg: 11.344827586206897, max: 31)
#
# Run: 59, exploration: 0.05169406930342616, score: 10
# Scores: (min: 8, avg: 11.322033898305085, max: 31)
#
# Run: 60, exploration: 0.04966213277390804, score: 9
# Scores: (min: 8, avg: 11.283333333333333, max: 31)
#
# Run: 61, exploration: 0.04771006548501318, score: 9
# Scores: (min: 8, avg: 11.245901639344263, max: 31)
#
# Run: 62, exploration: 0.04583472801998072, score: 9
# Scores: (min: 8, avg: 11.209677419354838, max: 31)
#
# Run: 63, exploration: 0.043812938841152796, score: 10
# Scores: (min: 8, avg: 11.19047619047619, max: 31)
#
# Run: 64, exploration: 0.041670929977297724, score: 11
# Scores: (min: 8, avg: 11.1875, max: 31)
#
# Run: 65, exploration: 0.040032972548509065, score: 9
# Scores: (min: 8, avg: 11.153846153846153, max: 31)
#
# Run: 66, exploration: 0.038075765743545126, score: 11
# Scores: (min: 8, avg: 11.151515151515152, max: 31)
#
# Run: 67, exploration: 0.03657912327863173, score: 9
# Scores: (min: 8, avg: 11.119402985074627, max: 31)
#
# Run: 68, exploration: 0.03514130927386981, score: 9
# Scores: (min: 8, avg: 11.088235294117647, max: 31)
#
# Run: 69, exploration: 0.033760011361539714, score: 9
# Scores: (min: 8, avg: 11.057971014492754, max: 31)
#
# Run: 70, exploration: 0.03227084302572862, score: 10
# Scores: (min: 8, avg: 11.042857142857143, max: 31)
#
# Run: 71, exploration: 0.030847362533106718, score: 10
# Scores: (min: 8, avg: 11.028169014084508, max: 31)
#
# Run: 72, exploration: 0.0279048474362789, score: 21
# Scores: (min: 8, avg: 11.166666666666666, max: 31)
#
# Run: 73, exploration: 0.026807992814067, score: 9
# Scores: (min: 8, avg: 11.136986301369863, max: 31)
#
# Run: 74, exploration: 0.02562548094765099, score: 10
# Scores: (min: 8, avg: 11.121621621621621, max: 31)
#
# Run: 75, exploration: 0.024250791254731636, score: 12
# Scores: (min: 8, avg: 11.133333333333333, max: 31)
#
# Run: 76, exploration: 0.023181078627322618, score: 10
# Scores: (min: 8, avg: 11.118421052631579, max: 31)
#
# Run: 77, exploration: 0.022158551474944856, score: 10
# Scores: (min: 8, avg: 11.103896103896103, max: 31)
#
# Run: 78, exploration: 0.02128756625768776, score: 9
# Scores: (min: 8, avg: 11.076923076923077, max: 31)
#
# Run: 79, exploration: 0.020348562734319765, score: 10
# Scores: (min: 8, avg: 11.063291139240507, max: 31)
#
# Run: 80, exploration: 0.01954872266561937, score: 9
# Scores: (min: 8, avg: 11.0375, max: 31)
#
# Run: 81, exploration: 0.018780321875645996, score: 9
# Scores: (min: 8, avg: 11.012345679012345, max: 31)
#
# Run: 82, exploration: 0.018042124582040707, score: 9
# Scores: (min: 8, avg: 10.987804878048781, max: 31)
# Run: 83, exploration: 0.01724627885940145, score: 10
# Scores: (min: 8, avg: 10.975903614457831, max: 31)
#
# Run: 84, exploration: 0.0165683801277891, score: 9
# Scores: (min: 8, avg: 10.952380952380953, max: 31)
#
# Run: 85, exploration: 0.01575835418494799, score: 11
# Scores: (min: 8, avg: 10.952941176470588, max: 31)
#
# Run: 86, exploration: 0.015215016325303928, score: 8
# Scores: (min: 8, avg: 10.918604651162791, max: 31)
#
# Run: 87, exploration: 0.01461696034160619, score: 9
# Scores: (min: 8, avg: 10.89655172413793, max: 31)
#
# Run: 88, exploration: 0.013972200057807112, score: 10
# Scores: (min: 8, avg: 10.886363636363637, max: 31)
#
# Run: 89, exploration: 0.013422995398979608, score: 9
# Scores: (min: 8, avg: 10.865168539325843, max: 31)
#
# Run: 90, exploration: 0.01283090141222608, score: 10
# Scores: (min: 8, avg: 10.855555555555556, max: 31)
#
# Run: 91, exploration: 0.012264924940880204, score: 10
# Scores: (min: 8, avg: 10.846153846153847, max: 31)
#
# Run: 92, exploration: 0.010605575411209664, score: 30
# Scores: (min: 8, avg: 11.054347826086957, max: 31)
#
# Run: 93, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.118279569892474, max: 31)
#
# Run: 94, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 11.414893617021276, max: 39)
#
# Run: 95, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 12.115789473684211, max: 78)
#
# Run: 96, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 12.53125, max: 78)
#
# Run: 97, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 12.917525773195877, max: 78)
#
# Run: 98, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 13.39795918367347, max: 78)
#
# Run: 99, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 13.686868686868687, max: 78)
#
# Run: 100, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 13.83, max: 78)
#
# Run: 101, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 14.03, max: 78)
#
# Run: 102, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 14.17, max: 78)
#
# Run: 103, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 14.34, max: 78)
#
# Run: 104, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 14.27, max: 78)
#
# Run: 105, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 14.38, max: 78)
#
# Run: 106, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.42, max: 78)
#
# Run: 107, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.45, max: 78)
#
# Run: 108, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.48, max: 78)
#
# Run: 109, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 14.5, max: 78)
#
# Run: 110, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.52, max: 78)
#
# Run: 111, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.54, max: 78)
#
# Run: 112, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 14.65, max: 78)
#
# Run: 113, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.65, max: 78)
#
# Run: 114, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.67, max: 78)
#
# Run: 115, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.69, max: 78)
#
# Run: 116, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.7, max: 78)
#
# Run: 117, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.77, max: 78)
#
# Run: 118, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.82, max: 78)
#
# Run: 119, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.86, max: 78)
#
# Run: 120, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.93, max: 78)
#
# Run: 121, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.08, max: 78)
#
# Run: 122, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.12, max: 78)
#
# Run: 123, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.11, max: 78)
#
# Run: 124, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.19, max: 78)
#
# Run: 125, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.22, max: 78)
#
# Run: 126, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.27, max: 78)
#
# Run: 127, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.29, max: 78)
#
# Run: 128, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.31, max: 78)
#
# Run: 129, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.32, max: 78)
#
# Run: 130, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 15.51, max: 78)
#
# Run: 131, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 15.76, max: 78)
#
# Run: 132, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.85, max: 78)
#
# Run: 133, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 16.13, max: 78)
#
# Run: 134, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 16.12, max: 78)
#
# Run: 135, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 16.47, max: 78)
#
# Run: 136, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 16.81, max: 78)
#
# Run: 137, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 17.2, max: 78)
#
# Run: 138, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.18, max: 78)
#
# Run: 139, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 17.51, max: 78)
#
# Run: 140, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.54, max: 78)
#
# Run: 141, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.59, max: 78)
#
# Run: 142, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.65, max: 78)
#
# Run: 143, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.66, max: 78)
#
# Run: 144, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 18.88, max: 134)
#
# Run: 145, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 19.26, max: 134)
#
# Run: 146, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 20.41, max: 134)
#
# Run: 147, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 20.64, max: 134)
#
# Run: 148, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 20.84, max: 134)
#
# Run: 149, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 20.96, max: 134)
#
# Run: 150, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 21.12, max: 134)
#
# Run: 151, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 21.37, max: 134)
#
# Run: 152, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 21.54, max: 134)
#
# Run: 153, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 21.73, max: 134)
#
# Run: 154, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 21.91, max: 134)
#
# Run: 155, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 22.17, max: 134)
#
# Run: 156, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 22.56, max: 134)
#
# Run: 157, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 22.84, max: 134)
#
# Run: 158, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 23.1, max: 134)
#
# Run: 159, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 23.23, max: 134)
#
# Run: 160, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 23.37, max: 134)
#
# Run: 161, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 23.62, max: 134)
#
# Run: 162, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 23.99, max: 134)
#
# Run: 163, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 24.26, max: 134)
#
# Run: 164, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 24.54, max: 134)
#
# Run: 165, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 24.78, max: 134)
#
# Run: 166, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 24.99, max: 134)
#
# Run: 167, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 25.15, max: 134)
#
# Run: 168, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 25.33, max: 134)
#
# Run: 169, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 25.49, max: 134)
#
# Run: 170, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 25.65, max: 134)
#
# Run: 171, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 25.81, max: 134)
#
# Run: 172, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 25.94, max: 134)
#
# Run: 173, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 26.18, max: 134)
#
# Run: 174, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 26.47, max: 134)
#
# Run: 175, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 26.86, max: 134)
#
# Run: 176, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 27.03, max: 134)
#
# Run: 177, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 27.21, max: 134)
#
# Run: 178, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 27.47, max: 134)
#
# Run: 179, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 27.74, max: 134)
#
# Run: 180, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 27.91, max: 134)
#
# Run: 181, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 28.13, max: 134)
#
# Run: 182, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 28.33, max: 134)
#
# Run: 183, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 28.67, max: 134)
# Run: 184, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 28.95, max: 134)
#
# Run: 185, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 29.25, max: 134)
#
# Run: 186, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 29.53, max: 134)
#
# Run: 187, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 29.8, max: 134)
#
# Run: 188, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 30.05, max: 134)
#
# Run: 189, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 30.48, max: 134)
#
# Run: 190, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 30.65, max: 134)
#
# Run: 191, exploration: 0.01, score: 45
# Scores: (min: 10, avg: 31, max: 134)
#
# Run: 192, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 30.98, max: 134)
#
# Run: 193, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 31.16, max: 134)
#
# Run: 194, exploration: 0.01, score: 43
# Scores: (min: 10, avg: 31.2, max: 134)
#
# Run: 195, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 30.93, max: 134)
#
# Run: 196, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 30.71, max: 134)
#
# Run: 197, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 30.56, max: 134)
#
# Run: 198, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 30.29, max: 134)
#
# Run: 199, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 30.27, max: 134)
#
# Run: 200, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 30.66, max: 134)
#
# Run: 201, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 31.06, max: 134)
#
# Run: 202, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 31.53, max: 134)
#
# Run: 203, exploration: 0.01, score: 85
# Scores: (min: 10, avg: 32.08, max: 134)
#
# Run: 204, exploration: 0.01, score: 53
# Scores: (min: 10, avg: 32.37, max: 134)
#
# Run: 205, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 33.7, max: 157)
#
# Run: 206, exploration: 0.01, score: 68
# Scores: (min: 10, avg: 34.18, max: 157)
#
# Run: 207, exploration: 0.01, score: 221
# Scores: (min: 10, avg: 36.22, max: 221)
#
# Run: 208, exploration: 0.01, score: 78
# Scores: (min: 10, avg: 36.84, max: 221)
#
# Run: 209, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 37.33, max: 221)
#
# Run: 210, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 38.2, max: 221)
#
# Run: 211, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 39.26, max: 221)
#
# Run: 212, exploration: 0.01, score: 123
# Scores: (min: 10, avg: 40.29, max: 221)
#
# Run: 213, exploration: 0.01, score: 55
# Scores: (min: 10, avg: 40.71, max: 221)
#
# Run: 214, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 41.58, max: 221)
#
# Run: 215, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 43.5, max: 221)
#
# Run: 216, exploration: 0.01, score: 96
# Scores: (min: 10, avg: 44.31, max: 221)
#
# Run: 217, exploration: 0.01, score: 248
# Scores: (min: 10, avg: 46.6, max: 248)
#
# Run: 218, exploration: 0.01, score: 287
# Scores: (min: 10, avg: 49.3, max: 287)
#
# Run: 219, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 50.38, max: 287)
#
# Run: 220, exploration: 0.01, score: 244
# Scores: (min: 10, avg: 52.65, max: 287)
#
# Run: 221, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 53.96, max: 287)
#
# Run: 222, exploration: 0.01, score: 111
# Scores: (min: 10, avg: 54.92, max: 287)
#
# Run: 223, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 56.4, max: 287)
#
# Run: 224, exploration: 0.01, score: 189
# Scores: (min: 10, avg: 58.12, max: 287)
#
# Run: 225, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 59.19, max: 287)
#
# Run: 226, exploration: 0.01, score: 287
# Scores: (min: 10, avg: 61.92, max: 287)
#
# Run: 227, exploration: 0.01, score: 348
# Scores: (min: 10, avg: 65.26, max: 348)
#
# Run: 228, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 67.04, max: 348)
#
# Run: 229, exploration: 0.01, score: 225
# Scores: (min: 10, avg: 69.17, max: 348)
#
# Run: 230, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 70.38, max: 348)
#
# Run: 231, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 71.13, max: 348)
#
# Run: 232, exploration: 0.01, score: 354
# Scores: (min: 10, avg: 74.47, max: 354)
#
# Run: 233, exploration: 0.01, score: 242
# Scores: (min: 10, avg: 76.5, max: 354)
#
# Run: 234, exploration: 0.01, score: 279
# Scores: (min: 10, avg: 79.17, max: 354)
#
# Run: 235, exploration: 0.01, score: 288
# Scores: (min: 10, avg: 81.61, max: 354)
#
# Run: 236, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 82.82, max: 354)
#
# Run: 237, exploration: 0.01, score: 125
# Scores: (min: 10, avg: 83.59, max: 354)
#
# Run: 238, exploration: 0.01, score: 57
# Scores: (min: 11, avg: 84.06, max: 354)
#
# Run: 239, exploration: 0.01, score: 187
# Scores: (min: 11, avg: 85.5, max: 354)
#
# Run: 240, exploration: 0.01, score: 185
# Scores: (min: 12, avg: 87.24, max: 354)
#
# Run: 241, exploration: 0.01, score: 191
# Scores: (min: 12, avg: 89, max: 354)
#
# Run: 242, exploration: 0.01, score: 239
# Scores: (min: 12, avg: 91.24, max: 354)
#
# Run: 243, exploration: 0.01, score: 269
# Scores: (min: 22, avg: 93.81, max: 354)
#
# Run: 244, exploration: 0.01, score: 255
# Scores: (min: 22, avg: 95.02, max: 354)
#
# Run: 245, exploration: 0.01, score: 500
# Scores: (min: 22, avg: 99.54, max: 500)
#
# Run: 246, exploration: 0.01, score: 209
# Scores: (min: 22, avg: 100.39, max: 500)
#
# Run: 247, exploration: 0.01, score: 233
# Scores: (min: 22, avg: 102.4, max: 500)
#
# Run: 248, exploration: 0.01, score: 134
# Scores: (min: 22, avg: 103.44, max: 500)
#
# Run: 249, exploration: 0.01, score: 328
# Scores: (min: 23, avg: 106.5, max: 500)
#
# Run: 250, exploration: 0.01, score: 148
# Scores: (min: 23, avg: 107.73, max: 500)
#
# Run: 251, exploration: 0.01, score: 190
# Scores: (min: 23, avg: 109.28, max: 500)
#
# Run: 252, exploration: 0.01, score: 186
# Scores: (min: 23, avg: 110.86, max: 500)
#
# Run: 253, exploration: 0.01, score: 195
# Scores: (min: 23, avg: 112.52, max: 500)
#
# Run: 254, exploration: 0.01, score: 167
# Scores: (min: 23, avg: 113.92, max: 500)
#
# Run: 255, exploration: 0.01, score: 197
# Scores: (min: 23, avg: 115.54, max: 500)
#
# Run: 256, exploration: 0.01, score: 185
# Scores: (min: 23, avg: 116.92, max: 500)
#
# Run: 257, exploration: 0.01, score: 129
# Scores: (min: 23, avg: 117.82, max: 500)
#
# Run: 258, exploration: 0.01, score: 231
# Scores: (min: 23, avg: 119.78, max: 500)
#
# Run: 259, exploration: 0.01, score: 254
# Scores: (min: 23, avg: 122.09, max: 500)
#
# Run: 260, exploration: 0.01, score: 148
# Scores: (min: 25, avg: 123.34, max: 500)
#
# Run: 261, exploration: 0.01, score: 370
# Scores: (min: 25, avg: 126.7, max: 500)
#
# Run: 262, exploration: 0.01, score: 285
# Scores: (min: 25, avg: 129.09, max: 500)
#
# Run: 263, exploration: 0.01, score: 223
# Scores: (min: 25, avg: 130.95, max: 500)
#
# Run: 264, exploration: 0.01, score: 140
# Scores: (min: 25, avg: 131.96, max: 500)
#
# Run: 265, exploration: 0.01, score: 172
# Scores: (min: 25, avg: 133.35, max: 500)
#
# Run: 266, exploration: 0.01, score: 333
# Scores: (min: 25, avg: 136.36, max: 500)
#
# Run: 267, exploration: 0.01, score: 250
# Scores: (min: 25, avg: 138.61, max: 500)
#
# Run: 268, exploration: 0.01, score: 221
# Scores: (min: 25, avg: 140.55, max: 500)
#
# Run: 269, exploration: 0.01, score: 138
# Scores: (min: 26, avg: 141.68, max: 500)
#
# Run: 270, exploration: 0.01, score: 500
# Scores: (min: 26, avg: 146.42, max: 500)
#
# Run: 271, exploration: 0.01, score: 161
# Scores: (min: 26, avg: 147.77, max: 500)
#
# Run: 272, exploration: 0.01, score: 352
# Scores: (min: 26, avg: 150.95, max: 500)
#
# Run: 273, exploration: 0.01, score: 177
# Scores: (min: 26, avg: 152.39, max: 500)
#
# Run: 274, exploration: 0.01, score: 192
# Scores: (min: 26, avg: 153.92, max: 500)
#
# Run: 275, exploration: 0.01, score: 165
# Scores: (min: 26, avg: 155.06, max: 500)
#
# Run: 276, exploration: 0.01, score: 265
# Scores: (min: 26, avg: 157.44, max: 500)
#
# Run: 277, exploration: 0.01, score: 303
# Scores: (min: 26, avg: 160.19, max: 500)
#
# Run: 278, exploration: 0.01, score: 147
# Scores: (min: 26, avg: 161.31, max: 500)
#
# Run: 279, exploration: 0.01, score: 233
# Scores: (min: 26, avg: 163.27, max: 500)
#
# Run: 280, exploration: 0.01, score: 182
# Scores: (min: 27, avg: 164.83, max: 500)
#
# Run: 281, exploration: 0.01, score: 171
# Scores: (min: 27, avg: 166.23, max: 500)
#
# Run: 282, exploration: 0.01, score: 225
# Scores: (min: 27, avg: 168.19, max: 500)
#
# Run: 283, exploration: 0.01, score: 303
# Scores: (min: 27, avg: 170.78, max: 500)
#
# Run: 284, exploration: 0.01, score: 175
# Scores: (min: 27, avg: 172.16, max: 500)
#
# Run: 285, exploration: 0.01, score: 455
# Scores: (min: 27, avg: 176.3, max: 500)
# Run: 286, exploration: 0.01, score: 492
# Scores: (min: 27, avg: 180.86, max: 500)
#
# Run: 287, exploration: 0.01, score: 455
# Scores: (min: 27, avg: 185.05, max: 500)
#
# Run: 288, exploration: 0.01, score: 142
# Scores: (min: 27, avg: 186.12, max: 500)
#
# Run: 289, exploration: 0.01, score: 251
# Scores: (min: 27, avg: 188.11, max: 500)
#
# Run: 290, exploration: 0.01, score: 171
# Scores: (min: 28, avg: 189.55, max: 500)
#
# Run: 291, exploration: 0.01, score: 203
# Scores: (min: 28, avg: 191.13, max: 500)
#
# Run: 292, exploration: 0.01, score: 179
# Scores: (min: 30, avg: 192.64, max: 500)
#
# Run: 293, exploration: 0.01, score: 148
# Scores: (min: 30, avg: 193.77, max: 500)
#
# Run: 294, exploration: 0.01, score: 409
# Scores: (min: 30, avg: 197.43, max: 500)
#
# Solved in 194 runs, 294 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-13-3ec65b20e9c8> in cartpole()
#      85             if terminal:
#      86                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 87                 score_logger.add_score(step, run)
#      88                 break
#      89             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

#Experiment 2 - keep the decay rate (discount factor) from previous experiment and modify the learning rate

GAMMA = 0.99 # kept the decay rate from the previous experiment 
LEARNING_RATE = 0.0001 # changed learning rate from 0.001 to 0.0001 
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9558895783575597, score: 29
# Scores: (min: 29, avg: 29, max: 29)
#
# Run: 2, exploration: 0.8647077305675338, score: 21
# Scores: (min: 21, avg: 25, max: 29)
#
# Run: 3, exploration: 0.8224322824348486, score: 11
# Scores: (min: 11, avg: 20.333333333333332, max: 29)
#
# Run: 4, exploration: 0.7744209942832988, score: 13
# Scores: (min: 11, avg: 18.5, max: 29)
#
# Run: 5, exploration: 0.6629680834613705, score: 32
# Scores: (min: 11, avg: 21.2, max: 32)
#
# Run: 6, exploration: 0.6149486215357263, score: 16
# Scores: (min: 11, avg: 20.333333333333332, max: 32)
#
# Run: 7, exploration: 0.567555222460375, score: 17
# Scores: (min: 11, avg: 19.857142857142858, max: 32)
#
# Run: 8, exploration: 0.5344229416520513, score: 13
# Scores: (min: 11, avg: 19, max: 32)
#
# Run: 9, exploration: 0.483444593917636, score: 21
# Scores: (min: 11, avg: 19.22222222222222, max: 32)
#
# Run: 10, exploration: 0.46444185833082485, score: 9
# Scores: (min: 9, avg: 18.2, max: 32)
#
# Run: 11, exploration: 0.4417353564707963, score: 11
# Scores: (min: 9, avg: 17.545454545454547, max: 32)
#
# Run: 12, exploration: 0.4180382776616619, score: 12
# Scores: (min: 9, avg: 17.083333333333332, max: 32)
#
# Run: 13, exploration: 0.37251769488706843, score: 24
# Scores: (min: 9, avg: 17.615384615384617, max: 32)
#
# Run: 14, exploration: 0.35608578229633, score: 10
# Scores: (min: 9, avg: 17.071428571428573, max: 32)
#
# Run: 15, exploration: 0.3386767948568688, score: 11
# Scores: (min: 9, avg: 16.666666666666668, max: 32)
#
# Run: 16, exploration: 0.3253644408394192, score: 9
# Scores: (min: 9, avg: 16.1875, max: 32)
#
# Run: 17, exploration: 0.31101247816653554, score: 10
# Scores: (min: 9, avg: 15.823529411764707, max: 32)
#
# Run: 18, exploration: 0.30028896908517405, score: 8
# Scores: (min: 8, avg: 15.38888888888889, max: 32)
#
# Run: 19, exploration: 0.2827589419554058, score: 13
# Scores: (min: 8, avg: 15.263157894736842, max: 32)
#
# Run: 20, exploration: 0.27164454854530906, score: 9
# Scores: (min: 8, avg: 14.95, max: 32)
#
# Run: 21, exploration: 0.2609670281126685, score: 9
# Scores: (min: 8, avg: 14.666666666666666, max: 32)
#
# Run: 22, exploration: 0.2507092085103961, score: 9
# Scores: (min: 8, avg: 14.409090909090908, max: 32)
#
# Run: 23, exploration: 0.2408545925762412, score: 9
# Scores: (min: 8, avg: 14.173913043478262, max: 32)
#
# Run: 24, exploration: 0.2290792429684691, score: 11
# Scores: (min: 8, avg: 14.041666666666666, max: 32)
#
# Run: 25, exploration: 0.2189744609715989, score: 10
# Scores: (min: 8, avg: 13.88, max: 32)
#
# Run: 26, exploration: 0.20722748400265262, score: 12
# Scores: (min: 8, avg: 13.807692307692308, max: 32)
#
# Run: 27, exploration: 0.19709615934585656, score: 11
# Scores: (min: 8, avg: 13.703703703703704, max: 32)
#
# Run: 28, exploration: 0.18934890919900021, score: 9
# Scores: (min: 8, avg: 13.535714285714286, max: 32)
#
# Run: 29, exploration: 0.18190617987607657, score: 9
# Scores: (min: 8, avg: 13.379310344827585, max: 32)
#
# Run: 30, exploration: 0.17388222158237718, score: 10
# Scores: (min: 8, avg: 13.266666666666667, max: 32)
#
# Run: 31, exploration: 0.1662122034722543, score: 10
# Scores: (min: 8, avg: 13.161290322580646, max: 32)
#
# Run: 32, exploration: 0.1580861105294992, score: 11
# Scores: (min: 8, avg: 13.09375, max: 32)
#
# Run: 33, exploration: 0.15035730121053842, score: 11
# Scores: (min: 8, avg: 13.030303030303031, max: 32)
#
# Run: 34, exploration: 0.14372497725712216, score: 10
# Scores: (min: 8, avg: 12.941176470588236, max: 32)
#
# Run: 35, exploration: 0.13398475271138335, score: 15
# Scores: (min: 8, avg: 13, max: 32)
#
# Run: 36, exploration: 0.12743425563174798, score: 11
# Scores: (min: 8, avg: 12.944444444444445, max: 32)
#
# Run: 37, exploration: 0.11999500148501063, score: 13
# Scores: (min: 8, avg: 12.945945945945946, max: 32)
#
# Run: 38, exploration: 0.11299003011401039, score: 13
# Scores: (min: 8, avg: 12.947368421052632, max: 32)
#
# Run: 39, exploration: 0.10800599224428936, score: 10
# Scores: (min: 8, avg: 12.871794871794872, max: 32)
#
# Run: 40, exploration: 0.10221196540767843, score: 12
# Scores: (min: 8, avg: 12.85, max: 32)
#
# Run: 41, exploration: 0.09770335251664321, score: 10
# Scores: (min: 8, avg: 12.78048780487805, max: 32)
#
# Run: 42, exploration: 0.09339361644125409, score: 10
# Scores: (min: 8, avg: 12.714285714285714, max: 32)
#
# Run: 43, exploration: 0.08972259762946533, score: 9
# Scores: (min: 8, avg: 12.627906976744185, max: 32)
#
# Run: 44, exploration: 0.08662902049662846, score: 8
# Scores: (min: 8, avg: 12.522727272727273, max: 32)
#
# Run: 45, exploration: 0.08280777787605056, score: 10
# Scores: (min: 8, avg: 12.466666666666667, max: 32)
#
# Run: 46, exploration: 0.07836551983717477, score: 12
# Scores: (min: 8, avg: 12.456521739130435, max: 32)
#
# Run: 47, exploration: 0.07268942442628039, score: 16
# Scores: (min: 8, avg: 12.53191489361702, max: 32)
#
# Run: 48, exploration: 0.06129936495526111, score: 35
# Scores: (min: 8, avg: 13, max: 35)
#
# Run: 49, exploration: 0.05918580250061433, score: 8
# Scores: (min: 8, avg: 12.89795918367347, max: 35)
#
# Run: 50, exploration: 0.056575091797066025, score: 10
# Scores: (min: 8, avg: 12.84, max: 35)
#
# Run: 51, exploration: 0.05407954064343768, score: 10
# Scores: (min: 8, avg: 12.784313725490197, max: 35)
#
# Run: 52, exploration: 0.05169406930342616, score: 10
# Scores: (min: 8, avg: 12.73076923076923, max: 35)
#
# Run: 53, exploration: 0.0494138221100385, score: 10
# Scores: (min: 8, avg: 12.679245283018869, max: 35)
#
# Run: 54, exploration: 0.047234157581800176, score: 10
# Scores: (min: 8, avg: 12.62962962962963, max: 35)
#
# Run: 55, exploration: 0.04537752660798141, score: 9
# Scores: (min: 8, avg: 12.563636363636364, max: 35)
#
# Run: 56, exploration: 0.04359387414694703, score: 9
# Scores: (min: 8, avg: 12.5, max: 35)
#
# Run: 57, exploration: 0.041670929977297724, score: 10
# Scores: (min: 8, avg: 12.456140350877194, max: 35)
#
# Run: 58, exploration: 0.040032972548509065, score: 9
# Scores: (min: 8, avg: 12.39655172413793, max: 35)
#
# Run: 59, exploration: 0.0386526615487428, score: 8
# Scores: (min: 8, avg: 12.322033898305085, max: 35)
#
# Run: 60, exploration: 0.035317898767708356, score: 19
# Scores: (min: 8, avg: 12.433333333333334, max: 35)
#
# Run: 61, exploration: 0.033760011361539714, score: 10
# Scores: (min: 8, avg: 12.39344262295082, max: 35)
#
# Run: 62, exploration: 0.03178919665971424, score: 13
# Scores: (min: 8, avg: 12.403225806451612, max: 35)
#
# Run: 63, exploration: 0.027350922279685573, score: 31
# Scores: (min: 8, avg: 12.698412698412698, max: 35)
#
# Run: 64, exploration: 0.022381810029994047, score: 41
# Scores: (min: 8, avg: 13.140625, max: 41)
#
# Run: 65, exploration: 0.018874695352408037, score: 35
# Scores: (min: 8, avg: 13.476923076923077, max: 41)
#
# Run: 66, exploration: 0.016735314893855303, score: 25
# Scores: (min: 8, avg: 13.651515151515152, max: 41)
#
# Run: 67, exploration: 0.013626370684745774, score: 42
# Scores: (min: 8, avg: 14.074626865671641, max: 42)
#
# Run: 68, exploration: 0.01184203826198843, score: 29
# Scores: (min: 8, avg: 14.294117647058824, max: 42)
#
# Run: 69, exploration: 0.01098430721937979, score: 16
# Scores: (min: 8, avg: 14.318840579710145, max: 42)
#
# Run: 70, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.485714285714286, max: 42)
#
# Run: 71, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.52112676056338, max: 42)
#
# Run: 72, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 14.63888888888889, max: 42)
#
# Run: 73, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 14.849315068493151, max: 42)
#
# Run: 74, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 14.986486486486486, max: 42)
#
# Run: 75, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 15.146666666666667, max: 42)
#
# Run: 76, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.263157894736842, max: 42)
#
# Run: 77, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 15.519480519480519, max: 42)
#
# Run: 78, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 15.91025641025641, max: 46)
#
# Run: 79, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 16.11392405063291, max: 46)
#
# Run: 80, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 16.275, max: 46)
#
# Run: 81, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.296296296296298, max: 46)
#
# Run: 82, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.341463414634145, max: 46)
#
# Run: 83, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.44578313253012, max: 46)
# Run: 84, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 16.571428571428573, max: 46)
#
# Run: 85, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 16.694117647058825, max: 46)
#
# Run: 86, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 17.197674418604652, max: 60)
#
# Run: 87, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.344827586206897, max: 60)
#
# Run: 88, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 17.443181818181817, max: 60)
#
# Run: 89, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 17.528089887640448, max: 60)
#
# Run: 90, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 17.711111111111112, max: 60)
#
# Run: 91, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.714285714285715, max: 60)
#
# Run: 92, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 17.73913043478261, max: 60)
#
# Run: 93, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.731182795698924, max: 60)
#
# Run: 94, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 17.79787234042553, max: 60)
#
# Run: 95, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 17.873684210526317, max: 60)
#
# Run: 96, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 18.09375, max: 60)
#
# Run: 97, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 18.515463917525775, max: 60)
#
# Run: 98, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 18.724489795918366, max: 60)
#
# Run: 99, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 19.1010101010101, max: 60)
#
# Run: 100, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 19.26, max: 60)
#
# Run: 101, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 20.86, max: 189)
#
# Run: 102, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 21.74, max: 189)
#
# Run: 103, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 22.05, max: 189)
#
# Run: 104, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 22.17, max: 189)
#
# Run: 105, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 22.45, max: 189)
#
# Run: 106, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 22.8, max: 189)
#
# Run: 107, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 23.11, max: 189)
#
# Run: 108, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 23.46, max: 189)
#
# Run: 109, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 23.82, max: 189)
#
# Run: 110, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 24.17, max: 189)
#
# Run: 111, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 24.42, max: 189)
#
# Run: 112, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 24.58, max: 189)
#
# Run: 113, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 24.6, max: 189)
#
# Run: 114, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 24.87, max: 189)
#
# Run: 115, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 25.47, max: 189)
#
# Run: 116, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 25.94, max: 189)
#
# Run: 117, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 26.34, max: 189)
#
# Run: 118, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 26.99, max: 189)
#
# Run: 119, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 27.34, max: 189)
#
# Run: 120, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 27.65, max: 189)
#
# Run: 121, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 28.23, max: 189)
#
# Run: 122, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 28.72, max: 189)
#
# Run: 123, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 29.1, max: 189)
#
# Run: 124, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 29.82, max: 189)
#
# Run: 125, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 31.29, max: 189)
#
# Run: 126, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 32.26, max: 189)
#
# Run: 127, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 33.31, max: 189)
#
# Run: 128, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 33.91, max: 189)
#
# Run: 129, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 34.48, max: 189)
#
# Run: 130, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 35.61, max: 189)
#
# Run: 131, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 36.58, max: 189)
#
# Run: 132, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 37.74, max: 189)
#
# Run: 133, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 38.11, max: 189)
#
# Run: 134, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 38.45, max: 189)
#
# Run: 135, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 38.59, max: 189)
#
# Run: 136, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 39.28, max: 189)
#
# Run: 137, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 40.51, max: 189)
#
# Run: 138, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 40.75, max: 189)
#
# Run: 139, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 40.88, max: 189)
#
# Run: 140, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 41.04, max: 189)
#
# Run: 141, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 41.27, max: 189)
#
# Run: 142, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 41.49, max: 189)
#
# Run: 143, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 41.68, max: 189)
#
# Run: 144, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 41.92, max: 189)
#
# Run: 145, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 42.1, max: 189)
#
# Run: 146, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 42.45, max: 189)
#
# Run: 147, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 43.01, max: 189)
#
# Run: 148, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 43.1, max: 189)
#
# Run: 149, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 43.37, max: 189)
#
# Run: 150, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 43.73, max: 189)
#
# Run: 151, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 44.12, max: 189)
#
# Run: 152, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 44.35, max: 189)
#
# Run: 153, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 44.41, max: 189)
#
# Run: 154, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 44.55, max: 189)
#
# Run: 155, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 44.66, max: 189)
#
# Run: 156, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 44.87, max: 189)
#
# Run: 157, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 45.99, max: 189)
#
# Run: 158, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 46.43, max: 189)
#
# Run: 159, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 46.62, max: 189)
#
# Run: 160, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 47.36, max: 189)
#
# Run: 161, exploration: 0.01, score: 47
# Scores: (min: 13, avg: 47.73, max: 189)
#
# Run: 162, exploration: 0.01, score: 49
# Scores: (min: 16, avg: 48.09, max: 189)
#
# Run: 163, exploration: 0.01, score: 26
# Scores: (min: 16, avg: 48.04, max: 189)
#
# Run: 164, exploration: 0.01, score: 44
# Scores: (min: 16, avg: 48.07, max: 189)
#
# Run: 165, exploration: 0.01, score: 61
# Scores: (min: 16, avg: 48.33, max: 189)
#
# Run: 166, exploration: 0.01, score: 115
# Scores: (min: 16, avg: 49.23, max: 189)
#
# Run: 167, exploration: 0.01, score: 36
# Scores: (min: 16, avg: 49.17, max: 189)
#
# Run: 168, exploration: 0.01, score: 74
# Scores: (min: 16, avg: 49.62, max: 189)
#
# Run: 169, exploration: 0.01, score: 48
# Scores: (min: 16, avg: 49.94, max: 189)
#
# Run: 170, exploration: 0.01, score: 70
# Scores: (min: 16, avg: 50.38, max: 189)
#
# Run: 171, exploration: 0.01, score: 56
# Scores: (min: 16, avg: 50.77, max: 189)
#
# Run: 172, exploration: 0.01, score: 39
# Scores: (min: 16, avg: 50.93, max: 189)
#
# Run: 173, exploration: 0.01, score: 24
# Scores: (min: 16, avg: 50.87, max: 189)
#
# Run: 174, exploration: 0.01, score: 43
# Scores: (min: 16, avg: 51.05, max: 189)
#
# Run: 175, exploration: 0.01, score: 43
# Scores: (min: 16, avg: 51.21, max: 189)
#
# Run: 176, exploration: 0.01, score: 45
# Scores: (min: 16, avg: 51.42, max: 189)
#
# Run: 177, exploration: 0.01, score: 44
# Scores: (min: 16, avg: 51.51, max: 189)
#
# Run: 178, exploration: 0.01, score: 62
# Scores: (min: 16, avg: 51.67, max: 189)
#
# Run: 179, exploration: 0.01, score: 103
# Scores: (min: 16, avg: 52.38, max: 189)
#
# Run: 180, exploration: 0.01, score: 43
# Scores: (min: 16, avg: 52.52, max: 189)
#
# Run: 181, exploration: 0.01, score: 35
# Scores: (min: 16, avg: 52.69, max: 189)
#
# Run: 182, exploration: 0.01, score: 38
# Scores: (min: 16, avg: 52.87, max: 189)
#
# Run: 183, exploration: 0.01, score: 32
# Scores: (min: 16, avg: 52.94, max: 189)
#
# Run: 184, exploration: 0.01, score: 29
# Scores: (min: 16, avg: 52.96, max: 189)
#
# Run: 185, exploration: 0.01, score: 35
# Scores: (min: 16, avg: 53.04, max: 189)
# Run: 186, exploration: 0.01, score: 26
# Scores: (min: 16, avg: 52.7, max: 189)
#
# Run: 187, exploration: 0.01, score: 45
# Scores: (min: 16, avg: 52.85, max: 189)
#
# Run: 188, exploration: 0.01, score: 58
# Scores: (min: 16, avg: 53.17, max: 189)
#
# Run: 189, exploration: 0.01, score: 42
# Scores: (min: 16, avg: 53.34, max: 189)
#
# Run: 190, exploration: 0.01, score: 44
# Scores: (min: 16, avg: 53.44, max: 189)
#
# Run: 191, exploration: 0.01, score: 33
# Scores: (min: 16, avg: 53.59, max: 189)
#
# Run: 192, exploration: 0.01, score: 43
# Scores: (min: 16, avg: 53.82, max: 189)
#
# Run: 193, exploration: 0.01, score: 68
# Scores: (min: 16, avg: 54.33, max: 189)
#
# Run: 194, exploration: 0.01, score: 36
# Scores: (min: 16, avg: 54.45, max: 189)
#
# Run: 195, exploration: 0.01, score: 50
# Scores: (min: 16, avg: 54.7, max: 189)
#
# Run: 196, exploration: 0.01, score: 43
# Scores: (min: 16, avg: 54.74, max: 189)
#
# Run: 197, exploration: 0.01, score: 38
# Scores: (min: 16, avg: 54.53, max: 189)
#
# Run: 198, exploration: 0.01, score: 41
# Scores: (min: 16, avg: 54.55, max: 189)
#
# Run: 199, exploration: 0.01, score: 62
# Scores: (min: 16, avg: 54.61, max: 189)
#
# Run: 200, exploration: 0.01, score: 112
# Scores: (min: 16, avg: 55.38, max: 189)
#
# Run: 201, exploration: 0.01, score: 65
# Scores: (min: 16, avg: 54.14, max: 157)
#
# Run: 202, exploration: 0.01, score: 33
# Scores: (min: 16, avg: 53.38, max: 157)
#
# Run: 203, exploration: 0.01, score: 35
# Scores: (min: 16, avg: 53.31, max: 157)
#
# Run: 204, exploration: 0.01, score: 53
# Scores: (min: 16, avg: 53.59, max: 157)
#
# Run: 205, exploration: 0.01, score: 86
# Scores: (min: 16, avg: 53.85, max: 157)
#
# Run: 206, exploration: 0.01, score: 70
# Scores: (min: 16, avg: 54.04, max: 157)
#
# Run: 207, exploration: 0.01, score: 51
# Scores: (min: 16, avg: 54.07, max: 157)
#
# Run: 208, exploration: 0.01, score: 44
# Scores: (min: 16, avg: 54.03, max: 157)
#
# Run: 209, exploration: 0.01, score: 112
# Scores: (min: 16, avg: 54.58, max: 157)
#
# Run: 210, exploration: 0.01, score: 63
# Scores: (min: 16, avg: 54.77, max: 157)
#
# Run: 211, exploration: 0.01, score: 94
# Scores: (min: 16, avg: 55.35, max: 157)
#
# Run: 212, exploration: 0.01, score: 74
# Scores: (min: 16, avg: 55.81, max: 157)
#
# Run: 213, exploration: 0.01, score: 312
# Scores: (min: 16, avg: 58.67, max: 312)
#
# Run: 214, exploration: 0.01, score: 55
# Scores: (min: 16, avg: 58.85, max: 312)
#
# Run: 215, exploration: 0.01, score: 69
# Scores: (min: 16, avg: 58.83, max: 312)
#
# Run: 216, exploration: 0.01, score: 117
# Scores: (min: 16, avg: 59.44, max: 312)
#
# Run: 217, exploration: 0.01, score: 113
# Scores: (min: 16, avg: 60.07, max: 312)
#
# Run: 218, exploration: 0.01, score: 124
# Scores: (min: 16, avg: 60.58, max: 312)
#
# Run: 219, exploration: 0.01, score: 31
# Scores: (min: 16, avg: 60.41, max: 312)
#
# Run: 220, exploration: 0.01, score: 38
# Scores: (min: 16, avg: 60.39, max: 312)
#
# Run: 221, exploration: 0.01, score: 45
# Scores: (min: 16, avg: 60.17, max: 312)
#
# Run: 222, exploration: 0.01, score: 57
# Scores: (min: 16, avg: 60.16, max: 312)
#
# Run: 223, exploration: 0.01, score: 68
# Scores: (min: 16, avg: 60.37, max: 312)
#
# Run: 224, exploration: 0.01, score: 115
# Scores: (min: 16, avg: 60.69, max: 312)
#
# Run: 225, exploration: 0.01, score: 116
# Scores: (min: 16, avg: 60.28, max: 312)
#
# Run: 226, exploration: 0.01, score: 173
# Scores: (min: 16, avg: 60.92, max: 312)
#
# Run: 227, exploration: 0.01, score: 157
# Scores: (min: 16, avg: 61.33, max: 312)
#
# Run: 228, exploration: 0.01, score: 244
# Scores: (min: 16, avg: 63.08, max: 312)
#
# Run: 229, exploration: 0.01, score: 233
# Scores: (min: 16, avg: 64.75, max: 312)
#
# Run: 230, exploration: 0.01, score: 189
# Scores: (min: 16, avg: 65.41, max: 312)
#
# Run: 231, exploration: 0.01, score: 123
# Scores: (min: 16, avg: 65.57, max: 312)
#
# Run: 232, exploration: 0.01, score: 124
# Scores: (min: 16, avg: 65.54, max: 312)
#
# Run: 233, exploration: 0.01, score: 146
# Scores: (min: 16, avg: 66.52, max: 312)
#
# Run: 234, exploration: 0.01, score: 119
# Scores: (min: 16, avg: 67.27, max: 312)
#
# Run: 235, exploration: 0.01, score: 126
# Scores: (min: 16, avg: 68.24, max: 312)
#
# Run: 236, exploration: 0.01, score: 122
# Scores: (min: 16, avg: 68.66, max: 312)
#
# Run: 237, exploration: 0.01, score: 126
# Scores: (min: 16, avg: 68.56, max: 312)
#
# Run: 238, exploration: 0.01, score: 111
# Scores: (min: 16, avg: 69.3, max: 312)
#
# Run: 239, exploration: 0.01, score: 190
# Scores: (min: 16, avg: 70.97, max: 312)
#
# Run: 240, exploration: 0.01, score: 187
# Scores: (min: 16, avg: 72.56, max: 312)
#
# Run: 241, exploration: 0.01, score: 180
# Scores: (min: 16, avg: 74.03, max: 312)
#
# Run: 242, exploration: 0.01, score: 500
# Scores: (min: 16, avg: 78.71, max: 500)
#
# Run: 243, exploration: 0.01, score: 500
# Scores: (min: 16, avg: 83.43, max: 500)
#
# Run: 244, exploration: 0.01, score: 500
# Scores: (min: 16, avg: 88.11, max: 500)
#
# Run: 245, exploration: 0.01, score: 416
# Scores: (min: 16, avg: 91.99, max: 500)
#
# Run: 246, exploration: 0.01, score: 488
# Scores: (min: 16, avg: 96.4, max: 500)
#
# Run: 247, exploration: 0.01, score: 273
# Scores: (min: 16, avg: 98.41, max: 500)
#
# Run: 248, exploration: 0.01, score: 236
# Scores: (min: 16, avg: 100.33, max: 500)
#
# Run: 249, exploration: 0.01, score: 337
# Scores: (min: 16, avg: 103.35, max: 500)
#
# Run: 250, exploration: 0.01, score: 392
# Scores: (min: 16, avg: 106.81, max: 500)
#
# Run: 251, exploration: 0.01, score: 500
# Scores: (min: 16, avg: 111.32, max: 500)
#
# Run: 252, exploration: 0.01, score: 500
# Scores: (min: 16, avg: 115.99, max: 500)
#
# Run: 253, exploration: 0.01, score: 500
# Scores: (min: 20, avg: 120.83, max: 500)
#
# Run: 254, exploration: 0.01, score: 500
# Scores: (min: 20, avg: 125.59, max: 500)
#
# Run: 255, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 130.39, max: 500)
#
# Run: 256, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 135.09, max: 500)
#
# Run: 257, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 138.87, max: 500)
#
# Run: 258, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 143.34, max: 500)
#
# Run: 259, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 148.07, max: 500)
#
# Run: 260, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 152.14, max: 500)
#
# Run: 261, exploration: 0.01, score: 327
# Scores: (min: 24, avg: 154.94, max: 500)
#
# Run: 262, exploration: 0.01, score: 367
# Scores: (min: 24, avg: 158.12, max: 500)
#
# Run: 263, exploration: 0.01, score: 295
# Scores: (min: 24, avg: 160.81, max: 500)
#
# Run: 264, exploration: 0.01, score: 362
# Scores: (min: 24, avg: 163.99, max: 500)
#
# Run: 265, exploration: 0.01, score: 467
# Scores: (min: 24, avg: 168.05, max: 500)
#
# Run: 266, exploration: 0.01, score: 443
# Scores: (min: 24, avg: 171.33, max: 500)
#
# Run: 267, exploration: 0.01, score: 443
# Scores: (min: 24, avg: 175.4, max: 500)
#
# Run: 268, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 179.66, max: 500)
#
# Run: 269, exploration: 0.01, score: 444
# Scores: (min: 24, avg: 183.62, max: 500)
#
# Run: 270, exploration: 0.01, score: 340
# Scores: (min: 24, avg: 186.32, max: 500)
#
# Run: 271, exploration: 0.01, score: 248
# Scores: (min: 24, avg: 188.24, max: 500)
#
# Run: 272, exploration: 0.01, score: 334
# Scores: (min: 24, avg: 191.19, max: 500)
#
# Run: 273, exploration: 0.01, score: 271
# Scores: (min: 26, avg: 193.66, max: 500)
#
# Run: 274, exploration: 0.01, score: 500
# Scores: (min: 26, avg: 198.23, max: 500)
#
# Solved in 174 runs, 274 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-19-b2015a74cc30> in cartpole()
#      86             if terminal:
#      87                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 88                 score_logger.add_score(step, run)
#      89                 break
#      90             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

#Experiment 3 - keep the decay rate and learning rate from previous experiments and modify exploration

GAMMA = 0.99 # kept the decay rate from the previous experiment 
LEARNING_RATE = 0.0001 # kept the learning rate from the previous experiment
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 0.75        # changed from 1.0 to 0.75
EXPLORATION_MIN = 0.2         # changed from 0.01 to 0.2
EXPLORATION_DECAY = 0.75      # changed from 0.995 to 0.75
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.75, score: 12
# Scores: (min: 12, avg: 12, max: 12)
#
# Run: 2, exploration: 0.31640625, score: 11
# Scores: (min: 11, avg: 11.5, max: 12)
#
# Run: 3, exploration: 0.2, score: 9
# Scores: (min: 9, avg: 10.666666666666666, max: 12)
#
# Run: 4, exploration: 0.2, score: 11
# Scores: (min: 9, avg: 10.75, max: 12)
#
# Run: 5, exploration: 0.2, score: 9
# Scores: (min: 9, avg: 10.4, max: 12)
#
# Run: 6, exploration: 0.2, score: 12
# Scores: (min: 9, avg: 10.666666666666666, max: 12)
#
# Run: 7, exploration: 0.2, score: 11
# Scores: (min: 9, avg: 10.714285714285714, max: 12)
#
# Run: 8, exploration: 0.2, score: 9
# Scores: (min: 9, avg: 10.5, max: 12)
#
# Run: 9, exploration: 0.2, score: 9
# Scores: (min: 9, avg: 10.333333333333334, max: 12)
#
# Run: 10, exploration: 0.2, score: 11
# Scores: (min: 9, avg: 10.4, max: 12)
#
# Run: 11, exploration: 0.2, score: 9
# Scores: (min: 9, avg: 10.272727272727273, max: 12)
#
# Run: 12, exploration: 0.2, score: 9
# Scores: (min: 9, avg: 10.166666666666666, max: 12)
#
# Run: 13, exploration: 0.2, score: 10
# Scores: (min: 9, avg: 10.153846153846153, max: 12)
#
# Run: 14, exploration: 0.2, score: 9
# Scores: (min: 9, avg: 10.071428571428571, max: 12)
#
# Run: 15, exploration: 0.2, score: 10
# Scores: (min: 9, avg: 10.066666666666666, max: 12)
#
# Run: 16, exploration: 0.2, score: 10
# Scores: (min: 9, avg: 10.0625, max: 12)
#
# Run: 17, exploration: 0.2, score: 10
# Scores: (min: 9, avg: 10.058823529411764, max: 12)
#
# Run: 18, exploration: 0.2, score: 11
# Scores: (min: 9, avg: 10.11111111111111, max: 12)
#
# Run: 19, exploration: 0.2, score: 12
# Scores: (min: 9, avg: 10.210526315789474, max: 12)
#
# Run: 20, exploration: 0.2, score: 8
# Scores: (min: 8, avg: 10.1, max: 12)
#
# Run: 21, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 10.19047619047619, max: 12)
#
# Run: 22, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.181818181818182, max: 12)
#
# Run: 23, exploration: 0.2, score: 8
# Scores: (min: 8, avg: 10.08695652173913, max: 12)
#
# Run: 24, exploration: 0.2, score: 13
# Scores: (min: 8, avg: 10.208333333333334, max: 13)
#
# Run: 25, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 10.16, max: 13)
#
# Run: 26, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.153846153846153, max: 13)
#
# Run: 27, exploration: 0.2, score: 8
# Scores: (min: 8, avg: 10.074074074074074, max: 13)
#
# Run: 28, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 10.035714285714286, max: 13)
#
# Run: 29, exploration: 0.2, score: 11
# Scores: (min: 8, avg: 10.068965517241379, max: 13)
#
# Run: 30, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 10.033333333333333, max: 13)
#
# Run: 31, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.03225806451613, max: 13)
#
# Run: 32, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.03125, max: 13)
#
# Run: 33, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 10.090909090909092, max: 13)
#
# Run: 34, exploration: 0.2, score: 13
# Scores: (min: 8, avg: 10.176470588235293, max: 13)
#
# Run: 35, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.17142857142857, max: 13)
#
# Run: 36, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.166666666666666, max: 13)
#
# Run: 37, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 10.135135135135135, max: 13)
#
# Run: 38, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 10.105263157894736, max: 13)
#
# Run: 39, exploration: 0.2, score: 11
# Scores: (min: 8, avg: 10.128205128205128, max: 13)
#
# Run: 40, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 10.1, max: 13)
#
# Run: 41, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 10.073170731707316, max: 13)
#
# Run: 42, exploration: 0.2, score: 13
# Scores: (min: 8, avg: 10.142857142857142, max: 13)
#
# Run: 43, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 10.116279069767442, max: 13)
#
# Run: 44, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 10.090909090909092, max: 13)
#
# Run: 45, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.088888888888889, max: 13)
#
# Run: 46, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 10.130434782608695, max: 13)
#
# Run: 47, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 10.170212765957446, max: 13)
#
# Run: 48, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.166666666666666, max: 13)
#
# Run: 49, exploration: 0.2, score: 13
# Scores: (min: 8, avg: 10.224489795918368, max: 13)
#
# Run: 50, exploration: 0.2, score: 14
# Scores: (min: 8, avg: 10.3, max: 14)
#
# Run: 51, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.294117647058824, max: 14)
#
# Run: 52, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 10.326923076923077, max: 14)
#
# Run: 53, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.320754716981131, max: 14)
#
# Run: 54, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 10.296296296296296, max: 14)
#
# Run: 55, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.290909090909091, max: 14)
#
# Run: 56, exploration: 0.2, score: 11
# Scores: (min: 8, avg: 10.303571428571429, max: 14)
#
# Run: 57, exploration: 0.2, score: 11
# Scores: (min: 8, avg: 10.31578947368421, max: 14)
#
# Run: 58, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.310344827586206, max: 14)
#
# Run: 59, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 10.338983050847459, max: 14)
#
# Run: 60, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 10.366666666666667, max: 14)
#
# Run: 61, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 10.39344262295082, max: 14)
#
# Run: 62, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 10.419354838709678, max: 14)
#
# Run: 63, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.412698412698413, max: 14)
#
# Run: 64, exploration: 0.2, score: 11
# Scores: (min: 8, avg: 10.421875, max: 14)
#
# Run: 65, exploration: 0.2, score: 11
# Scores: (min: 8, avg: 10.430769230769231, max: 14)
#
# Run: 66, exploration: 0.2, score: 16
# Scores: (min: 8, avg: 10.515151515151516, max: 16)
#
# Run: 67, exploration: 0.2, score: 16
# Scores: (min: 8, avg: 10.597014925373134, max: 16)
#
# Run: 68, exploration: 0.2, score: 13
# Scores: (min: 8, avg: 10.632352941176471, max: 16)
#
# Run: 69, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 10.623188405797102, max: 16)
#
# Run: 70, exploration: 0.2, score: 23
# Scores: (min: 8, avg: 10.8, max: 23)
#
# Run: 71, exploration: 0.2, score: 20
# Scores: (min: 8, avg: 10.929577464788732, max: 23)
#
# Run: 72, exploration: 0.2, score: 21
# Scores: (min: 8, avg: 11.069444444444445, max: 23)
#
# Run: 73, exploration: 0.2, score: 17
# Scores: (min: 8, avg: 11.150684931506849, max: 23)
#
# Run: 74, exploration: 0.2, score: 19
# Scores: (min: 8, avg: 11.256756756756756, max: 23)
#
# Run: 75, exploration: 0.2, score: 19
# Scores: (min: 8, avg: 11.36, max: 23)
#
# Run: 76, exploration: 0.2, score: 21
# Scores: (min: 8, avg: 11.486842105263158, max: 23)
#
# Run: 77, exploration: 0.2, score: 16
# Scores: (min: 8, avg: 11.545454545454545, max: 23)
#
# Run: 78, exploration: 0.2, score: 11
# Scores: (min: 8, avg: 11.538461538461538, max: 23)
#
# Run: 79, exploration: 0.2, score: 30
# Scores: (min: 8, avg: 11.772151898734178, max: 30)
#
# Run: 80, exploration: 0.2, score: 8
# Scores: (min: 8, avg: 11.725, max: 30)
#
# Run: 81, exploration: 0.2, score: 12
# Scores: (min: 8, avg: 11.728395061728396, max: 30)
#
# Run: 82, exploration: 0.2, score: 8
# Scores: (min: 8, avg: 11.682926829268293, max: 30)
#
# Run: 83, exploration: 0.2, score: 10
# Scores: (min: 8, avg: 11.662650602409638, max: 30)
#
# Run: 84, exploration: 0.2, score: 11
# Scores: (min: 8, avg: 11.654761904761905, max: 30)
#
# Run: 85, exploration: 0.2, score: 9
# Scores: (min: 8, avg: 11.623529411764705, max: 30)
#
# Run: 86, exploration: 0.2, score: 22
# Scores: (min: 8, avg: 11.744186046511627, max: 30)
#
# Run: 87, exploration: 0.2, score: 28
# Scores: (min: 8, avg: 11.931034482758621, max: 30)
#
# Run: 88, exploration: 0.2, score: 20
# Scores: (min: 8, avg: 12.022727272727273, max: 30)
#
# Run: 89, exploration: 0.2, score: 33
# Scores: (min: 8, avg: 12.258426966292134, max: 33)
#
# Run: 90, exploration: 0.2, score: 14
# Scores: (min: 8, avg: 12.277777777777779, max: 33)
#
# Run: 91, exploration: 0.2, score: 18
# Scores: (min: 8, avg: 12.340659340659341, max: 33)
#
# Run: 92, exploration: 0.2, score: 20
# Scores: (min: 8, avg: 12.423913043478262, max: 33)
#
# Run: 93, exploration: 0.2, score: 14
# Scores: (min: 8, avg: 12.440860215053764, max: 33)
#
# Run: 94, exploration: 0.2, score: 16
# Scores: (min: 8, avg: 12.47872340425532, max: 33)
#
# Run: 95, exploration: 0.2, score: 21
# Scores: (min: 8, avg: 12.56842105263158, max: 33)
# Run: 96, exploration: 0.2, score: 36
# Scores: (min: 8, avg: 12.8125, max: 36)
#
# Run: 97, exploration: 0.2, score: 20
# Scores: (min: 8, avg: 12.88659793814433, max: 36)
#
# Run: 98, exploration: 0.2, score: 20
# Scores: (min: 8, avg: 12.959183673469388, max: 36)
#
# Run: 99, exploration: 0.2, score: 31
# Scores: (min: 8, avg: 13.141414141414142, max: 36)
#
# Run: 100, exploration: 0.2, score: 34
# Scores: (min: 8, avg: 13.35, max: 36)
#
# Run: 101, exploration: 0.2, score: 31
# Scores: (min: 8, avg: 13.54, max: 36)
#
# Run: 102, exploration: 0.2, score: 45
# Scores: (min: 8, avg: 13.88, max: 45)
#
# Run: 103, exploration: 0.2, score: 38
# Scores: (min: 8, avg: 14.17, max: 45)
#
# Run: 104, exploration: 0.2, score: 18
# Scores: (min: 8, avg: 14.24, max: 45)
#
# Run: 105, exploration: 0.2, score: 35
# Scores: (min: 8, avg: 14.5, max: 45)
#
# Run: 106, exploration: 0.2, score: 14
# Scores: (min: 8, avg: 14.52, max: 45)
#
# Run: 107, exploration: 0.2, score: 14
# Scores: (min: 8, avg: 14.55, max: 45)
#
# Run: 108, exploration: 0.2, score: 18
# Scores: (min: 8, avg: 14.64, max: 45)
#
# Run: 109, exploration: 0.2, score: 24
# Scores: (min: 8, avg: 14.79, max: 45)
#
# Run: 110, exploration: 0.2, score: 17
# Scores: (min: 8, avg: 14.85, max: 45)
#
# Run: 111, exploration: 0.2, score: 43
# Scores: (min: 8, avg: 15.19, max: 45)
#
# Run: 112, exploration: 0.2, score: 15
# Scores: (min: 8, avg: 15.25, max: 45)
#
# Run: 113, exploration: 0.2, score: 43
# Scores: (min: 8, avg: 15.58, max: 45)
#
# Run: 114, exploration: 0.2, score: 29
# Scores: (min: 8, avg: 15.78, max: 45)
#
# Run: 115, exploration: 0.2, score: 40
# Scores: (min: 8, avg: 16.08, max: 45)
#
# Run: 116, exploration: 0.2, score: 42
# Scores: (min: 8, avg: 16.4, max: 45)
#
# Run: 117, exploration: 0.2, score: 32
# Scores: (min: 8, avg: 16.62, max: 45)
#
# Run: 118, exploration: 0.2, score: 32
# Scores: (min: 8, avg: 16.83, max: 45)
#
# Run: 119, exploration: 0.2, score: 57
# Scores: (min: 8, avg: 17.28, max: 57)
#
# Run: 120, exploration: 0.2, score: 49
# Scores: (min: 8, avg: 17.69, max: 57)
#
# Run: 121, exploration: 0.2, score: 23
# Scores: (min: 8, avg: 17.8, max: 57)
#
# Run: 122, exploration: 0.2, score: 22
# Scores: (min: 8, avg: 17.92, max: 57)
#
# Run: 123, exploration: 0.2, score: 49
# Scores: (min: 8, avg: 18.33, max: 57)
#
# Run: 124, exploration: 0.2, score: 92
# Scores: (min: 8, avg: 19.12, max: 92)
#
# Run: 125, exploration: 0.2, score: 125
# Scores: (min: 8, avg: 20.28, max: 125)
#
# Run: 126, exploration: 0.2, score: 138
# Scores: (min: 8, avg: 21.56, max: 138)
#
# Run: 127, exploration: 0.2, score: 137
# Scores: (min: 8, avg: 22.85, max: 138)
#
# Run: 128, exploration: 0.2, score: 74
# Scores: (min: 8, avg: 23.5, max: 138)
#
# Run: 129, exploration: 0.2, score: 60
# Scores: (min: 8, avg: 23.99, max: 138)
#
# Run: 130, exploration: 0.2, score: 39
# Scores: (min: 8, avg: 24.29, max: 138)
#
# Run: 131, exploration: 0.2, score: 40
# Scores: (min: 8, avg: 24.59, max: 138)
#
# Run: 132, exploration: 0.2, score: 38
# Scores: (min: 8, avg: 24.87, max: 138)
#
# Run: 133, exploration: 0.2, score: 88
# Scores: (min: 8, avg: 25.63, max: 138)
#
# Run: 134, exploration: 0.2, score: 73
# Scores: (min: 8, avg: 26.23, max: 138)
#
# Run: 135, exploration: 0.2, score: 65
# Scores: (min: 8, avg: 26.78, max: 138)
#
# Run: 136, exploration: 0.2, score: 53
# Scores: (min: 8, avg: 27.21, max: 138)
#
# Run: 137, exploration: 0.2, score: 37
# Scores: (min: 8, avg: 27.49, max: 138)
#
# Run: 138, exploration: 0.2, score: 42
# Scores: (min: 8, avg: 27.82, max: 138)
#
# Run: 139, exploration: 0.2, score: 25
# Scores: (min: 8, avg: 27.96, max: 138)
#
# Run: 140, exploration: 0.2, score: 18
# Scores: (min: 8, avg: 28.05, max: 138)
#
# Run: 141, exploration: 0.2, score: 19
# Scores: (min: 8, avg: 28.15, max: 138)
#
# Run: 142, exploration: 0.2, score: 23
# Scores: (min: 8, avg: 28.25, max: 138)
#
# Run: 143, exploration: 0.2, score: 42
# Scores: (min: 8, avg: 28.58, max: 138)
#
# Run: 144, exploration: 0.2, score: 49
# Scores: (min: 8, avg: 28.98, max: 138)
#
# Run: 145, exploration: 0.2, score: 44
# Scores: (min: 8, avg: 29.32, max: 138)
#
# Run: 146, exploration: 0.2, score: 47
# Scores: (min: 8, avg: 29.67, max: 138)
#
# Run: 147, exploration: 0.2, score: 47
# Scores: (min: 8, avg: 30.02, max: 138)
#
# Run: 148, exploration: 0.2, score: 40
# Scores: (min: 8, avg: 30.32, max: 138)
#
# Run: 149, exploration: 0.2, score: 41
# Scores: (min: 8, avg: 30.6, max: 138)
#
# Run: 150, exploration: 0.2, score: 37
# Scores: (min: 8, avg: 30.83, max: 138)
#
# Run: 151, exploration: 0.2, score: 38
# Scores: (min: 8, avg: 31.11, max: 138)
#
# Run: 152, exploration: 0.2, score: 50
# Scores: (min: 8, avg: 31.49, max: 138)
#
# Run: 153, exploration: 0.2, score: 48
# Scores: (min: 8, avg: 31.87, max: 138)
#
# Run: 154, exploration: 0.2, score: 59
# Scores: (min: 8, avg: 32.37, max: 138)
#
# Run: 155, exploration: 0.2, score: 40
# Scores: (min: 8, avg: 32.67, max: 138)
#
# Run: 156, exploration: 0.2, score: 38
# Scores: (min: 8, avg: 32.94, max: 138)
#
# Run: 157, exploration: 0.2, score: 37
# Scores: (min: 8, avg: 33.2, max: 138)
#
# Run: 158, exploration: 0.2, score: 29
# Scores: (min: 8, avg: 33.39, max: 138)
#
# Run: 159, exploration: 0.2, score: 34
# Scores: (min: 8, avg: 33.61, max: 138)
#
# Run: 160, exploration: 0.2, score: 47
# Scores: (min: 8, avg: 33.96, max: 138)
#
# Run: 161, exploration: 0.2, score: 34
# Scores: (min: 8, avg: 34.18, max: 138)
#
# Run: 162, exploration: 0.2, score: 111
# Scores: (min: 8, avg: 35.17, max: 138)
#
# Run: 163, exploration: 0.2, score: 86
# Scores: (min: 8, avg: 35.93, max: 138)
#
# Run: 164, exploration: 0.2, score: 99
# Scores: (min: 8, avg: 36.81, max: 138)
#
# Run: 165, exploration: 0.2, score: 50
# Scores: (min: 8, avg: 37.2, max: 138)
#
# Run: 166, exploration: 0.2, score: 51
# Scores: (min: 8, avg: 37.55, max: 138)
#
# Run: 167, exploration: 0.2, score: 44
# Scores: (min: 8, avg: 37.83, max: 138)
#
# Run: 168, exploration: 0.2, score: 29
# Scores: (min: 8, avg: 37.99, max: 138)
#
# Run: 169, exploration: 0.2, score: 38
# Scores: (min: 8, avg: 38.27, max: 138)
#
# Run: 170, exploration: 0.2, score: 61
# Scores: (min: 8, avg: 38.65, max: 138)
#
# Run: 171, exploration: 0.2, score: 100
# Scores: (min: 8, avg: 39.45, max: 138)
#
# Run: 172, exploration: 0.2, score: 50
# Scores: (min: 8, avg: 39.74, max: 138)
#
# Run: 173, exploration: 0.2, score: 69
# Scores: (min: 8, avg: 40.26, max: 138)
#
# Run: 174, exploration: 0.2, score: 89
# Scores: (min: 8, avg: 40.96, max: 138)
#
# Run: 175, exploration: 0.2, score: 67
# Scores: (min: 8, avg: 41.44, max: 138)
#
# Run: 176, exploration: 0.2, score: 67
# Scores: (min: 8, avg: 41.9, max: 138)
#
# Run: 177, exploration: 0.2, score: 40
# Scores: (min: 8, avg: 42.14, max: 138)
#
# Run: 178, exploration: 0.2, score: 103
# Scores: (min: 8, avg: 43.06, max: 138)
#
# Run: 179, exploration: 0.2, score: 64
# Scores: (min: 8, avg: 43.4, max: 138)
#
# Run: 180, exploration: 0.2, score: 62
# Scores: (min: 8, avg: 43.94, max: 138)
#
# Run: 181, exploration: 0.2, score: 90
# Scores: (min: 8, avg: 44.72, max: 138)
#
# Run: 182, exploration: 0.2, score: 75
# Scores: (min: 9, avg: 45.39, max: 138)
#
# Run: 183, exploration: 0.2, score: 120
# Scores: (min: 9, avg: 46.49, max: 138)
#
# Run: 184, exploration: 0.2, score: 195
# Scores: (min: 9, avg: 48.33, max: 195)
#
# Run: 185, exploration: 0.2, score: 89
# Scores: (min: 14, avg: 49.13, max: 195)
#
# Run: 186, exploration: 0.2, score: 99
# Scores: (min: 14, avg: 49.9, max: 195)
#
# Run: 187, exploration: 0.2, score: 80
# Scores: (min: 14, avg: 50.42, max: 195)
#
# Run: 188, exploration: 0.2, score: 62
# Scores: (min: 14, avg: 50.84, max: 195)
#
# Run: 189, exploration: 0.2, score: 55
# Scores: (min: 14, avg: 51.06, max: 195)
#
# Run: 190, exploration: 0.2, score: 88
# Scores: (min: 14, avg: 51.8, max: 195)
#
# Run: 191, exploration: 0.2, score: 79
# Scores: (min: 14, avg: 52.41, max: 195)
#
# Run: 192, exploration: 0.2, score: 133
# Scores: (min: 14, avg: 53.54, max: 195)
#
# Run: 193, exploration: 0.2, score: 126
# Scores: (min: 14, avg: 54.66, max: 195)
#
# Run: 194, exploration: 0.2, score: 106
# Scores: (min: 14, avg: 55.56, max: 195)
#
# Run: 195, exploration: 0.2, score: 214
# Scores: (min: 14, avg: 57.49, max: 214)
#
# Run: 196, exploration: 0.2, score: 199
# Scores: (min: 14, avg: 59.12, max: 214)
#
# Run: 197, exploration: 0.2, score: 168
# Scores: (min: 14, avg: 60.6, max: 214)
#
# Run: 198, exploration: 0.2, score: 204
# Scores: (min: 14, avg: 62.44, max: 214)
#
# Run: 199, exploration: 0.2, score: 137
# Scores: (min: 14, avg: 63.5, max: 214)
#
# Run: 200, exploration: 0.2, score: 199
# Scores: (min: 14, avg: 65.15, max: 214)
# Run: 201, exploration: 0.2, score: 149
# Scores: (min: 14, avg: 66.33, max: 214)
#
# Run: 202, exploration: 0.2, score: 221
# Scores: (min: 14, avg: 68.09, max: 221)
#
# Run: 203, exploration: 0.2, score: 151
# Scores: (min: 14, avg: 69.22, max: 221)
#
# Run: 204, exploration: 0.2, score: 183
# Scores: (min: 14, avg: 70.87, max: 221)
#
# Run: 205, exploration: 0.2, score: 153
# Scores: (min: 14, avg: 72.05, max: 221)
#
# Run: 206, exploration: 0.2, score: 213
# Scores: (min: 14, avg: 74.04, max: 221)
#
# Run: 207, exploration: 0.2, score: 500
# Scores: (min: 15, avg: 78.9, max: 500)
#
# Run: 208, exploration: 0.2, score: 324
# Scores: (min: 15, avg: 81.96, max: 500)
#
# Run: 209, exploration: 0.2, score: 204
# Scores: (min: 15, avg: 83.76, max: 500)
#
# Run: 210, exploration: 0.2, score: 198
# Scores: (min: 15, avg: 85.57, max: 500)
#
# Run: 211, exploration: 0.2, score: 221
# Scores: (min: 15, avg: 87.35, max: 500)
#
# Run: 212, exploration: 0.2, score: 275
# Scores: (min: 18, avg: 89.95, max: 500)
#
# Run: 213, exploration: 0.2, score: 205
# Scores: (min: 18, avg: 91.57, max: 500)
#
# Run: 214, exploration: 0.2, score: 233
# Scores: (min: 18, avg: 93.61, max: 500)
#
# Run: 215, exploration: 0.2, score: 238
# Scores: (min: 18, avg: 95.59, max: 500)
#
# Run: 216, exploration: 0.2, score: 267
# Scores: (min: 18, avg: 97.84, max: 500)
#
# Run: 217, exploration: 0.2, score: 256
# Scores: (min: 18, avg: 100.08, max: 500)
#
# Run: 218, exploration: 0.2, score: 231
# Scores: (min: 18, avg: 102.07, max: 500)
#
# Run: 219, exploration: 0.2, score: 238
# Scores: (min: 18, avg: 103.88, max: 500)
#
# Run: 220, exploration: 0.2, score: 225
# Scores: (min: 18, avg: 105.64, max: 500)
#
# Run: 221, exploration: 0.2, score: 376
# Scores: (min: 18, avg: 109.17, max: 500)
#
# Run: 222, exploration: 0.2, score: 229
# Scores: (min: 18, avg: 111.24, max: 500)
#
# Run: 223, exploration: 0.2, score: 360
# Scores: (min: 18, avg: 114.35, max: 500)
#
# Run: 224, exploration: 0.2, score: 472
# Scores: (min: 18, avg: 118.15, max: 500)
#
# Run: 225, exploration: 0.2, score: 200
# Scores: (min: 18, avg: 118.9, max: 500)
#
# Run: 226, exploration: 0.2, score: 326
# Scores: (min: 18, avg: 120.78, max: 500)
#
# Run: 227, exploration: 0.2, score: 237
# Scores: (min: 18, avg: 121.78, max: 500)
#
# Run: 228, exploration: 0.2, score: 304
# Scores: (min: 18, avg: 124.08, max: 500)
#
# Run: 229, exploration: 0.2, score: 279
# Scores: (min: 18, avg: 126.27, max: 500)
#
# Run: 230, exploration: 0.2, score: 500
# Scores: (min: 18, avg: 130.88, max: 500)
#
# Run: 231, exploration: 0.2, score: 389
# Scores: (min: 18, avg: 134.37, max: 500)
#
# Run: 232, exploration: 0.2, score: 422
# Scores: (min: 18, avg: 138.21, max: 500)
#
# Run: 233, exploration: 0.2, score: 287
# Scores: (min: 18, avg: 140.2, max: 500)
#
# Run: 234, exploration: 0.2, score: 281
# Scores: (min: 18, avg: 142.28, max: 500)
#
# Run: 235, exploration: 0.2, score: 493
# Scores: (min: 18, avg: 146.56, max: 500)
#
# Run: 236, exploration: 0.2, score: 470
# Scores: (min: 18, avg: 150.73, max: 500)
#
# Run: 237, exploration: 0.2, score: 410
# Scores: (min: 18, avg: 154.46, max: 500)
#
# Run: 238, exploration: 0.2, score: 500
# Scores: (min: 18, avg: 159.04, max: 500)
#
# Run: 239, exploration: 0.2, score: 460
# Scores: (min: 18, avg: 163.39, max: 500)
#
# Run: 240, exploration: 0.2, score: 395
# Scores: (min: 19, avg: 167.16, max: 500)
#
# Run: 241, exploration: 0.2, score: 456
# Scores: (min: 23, avg: 171.53, max: 500)
#
# Run: 242, exploration: 0.2, score: 285
# Scores: (min: 29, avg: 174.15, max: 500)
#
# Run: 243, exploration: 0.2, score: 326
# Scores: (min: 29, avg: 176.99, max: 500)
#
# Run: 244, exploration: 0.2, score: 246
# Scores: (min: 29, avg: 178.96, max: 500)
#
# Run: 245, exploration: 0.2, score: 341
# Scores: (min: 29, avg: 181.93, max: 500)
#
# Run: 246, exploration: 0.2, score: 307
# Scores: (min: 29, avg: 184.53, max: 500)
#
# Run: 247, exploration: 0.2, score: 310
# Scores: (min: 29, avg: 187.16, max: 500)
#
# Run: 248, exploration: 0.2, score: 332
# Scores: (min: 29, avg: 190.08, max: 500)
#
# Run: 249, exploration: 0.2, score: 270
# Scores: (min: 29, avg: 192.37, max: 500)
#
# Run: 250, exploration: 0.2, score: 277
# Scores: (min: 29, avg: 194.77, max: 500)
#
# Run: 251, exploration: 0.2, score: 240
# Scores: (min: 29, avg: 196.79, max: 500)
#
# Solved in 151 runs, 251 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-23-b60bbdc8a577> in cartpole()
#      86             if terminal:
#      87                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 88                 score_logger.add_score(step, run)
#      89                 break
#      90             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

# Experiment 4 - Only changing the learning rate to see its impact

GAMMA = 0.95  
LEARNING_RATE = 0.0008  # changed from 0.001 to 0.0008
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9046104802746175, score: 40
# Scores: (min: 40, avg: 40, max: 40)
#
# Run: 2, exploration: 0.7861544476842928, score: 29
# Scores: (min: 29, avg: 34.5, max: 40)
#
# Run: 3, exploration: 0.7328768546436799, score: 15
# Scores: (min: 15, avg: 28, max: 40)
#
# Run: 4, exploration: 0.6596532430440636, score: 22
# Scores: (min: 15, avg: 26.5, max: 40)
#
# Run: 5, exploration: 0.6274028820538087, score: 11
# Scores: (min: 11, avg: 23.4, max: 40)
#
# Run: 6, exploration: 0.6027415843082742, score: 9
# Scores: (min: 9, avg: 21, max: 40)
#
# Run: 7, exploration: 0.5290920728090721, score: 27
# Scores: (min: 9, avg: 21.857142857142858, max: 40)
#
# Run: 8, exploration: 0.4907693883854626, score: 16
# Scores: (min: 9, avg: 21.125, max: 40)
#
# Run: 9, exploration: 0.47147873742168567, score: 9
# Scores: (min: 9, avg: 19.77777777777778, max: 40)
#
# Run: 10, exploration: 0.4529463432347434, score: 9
# Scores: (min: 9, avg: 18.7, max: 40)
#
# Run: 11, exploration: 0.42013897252428334, score: 16
# Scores: (min: 9, avg: 18.454545454545453, max: 40)
#
# Run: 12, exploration: 0.3936343764094253, score: 14
# Scores: (min: 9, avg: 18.083333333333332, max: 40)
#
# Run: 13, exploration: 0.37627099809304654, score: 10
# Scores: (min: 9, avg: 17.46153846153846, max: 40)
#
# Run: 14, exploration: 0.3507711574848344, score: 15
# Scores: (min: 9, avg: 17.285714285714285, max: 40)
#
# Run: 15, exploration: 0.326999438029567, score: 15
# Scores: (min: 9, avg: 17.133333333333333, max: 40)
#
# Run: 16, exploration: 0.3033145315372582, score: 16
# Scores: (min: 9, avg: 17.0625, max: 40)
#
# Run: 17, exploration: 0.28417984116121187, score: 14
# Scores: (min: 9, avg: 16.88235294117647, max: 40)
#
# Run: 18, exploration: 0.2730095965279488, score: 9
# Scores: (min: 9, avg: 16.444444444444443, max: 40)
#
# Run: 19, exploration: 0.25966219297210513, score: 11
# Scores: (min: 9, avg: 16.157894736842106, max: 40)
#
# Run: 20, exploration: 0.24696734223472733, score: 11
# Scores: (min: 9, avg: 15.9, max: 40)
#
# Run: 21, exploration: 0.23489314109365644, score: 11
# Scores: (min: 9, avg: 15.666666666666666, max: 40)
#
# Run: 22, exploration: 0.22679417751985861, score: 8
# Scores: (min: 8, avg: 15.318181818181818, max: 40)
#
# Run: 23, exploration: 0.21570623976979014, score: 11
# Scores: (min: 8, avg: 15.130434782608695, max: 40)
#
# Run: 24, exploration: 0.20516038984972615, score: 11
# Scores: (min: 8, avg: 14.958333333333334, max: 40)
#
# Run: 25, exploration: 0.19709615934585656, score: 9
# Scores: (min: 8, avg: 14.72, max: 40)
#
# Run: 26, exploration: 0.1903004112552766, score: 8
# Scores: (min: 8, avg: 14.461538461538462, max: 40)
#
# Run: 27, exploration: 0.18099664897669618, score: 11
# Scores: (min: 8, avg: 14.333333333333334, max: 40)
#
# Run: 28, exploration: 0.17214774642209296, score: 11
# Scores: (min: 8, avg: 14.214285714285714, max: 40)
#
# Run: 29, exploration: 0.16291280823111093, score: 12
# Scores: (min: 8, avg: 14.137931034482758, max: 40)
#
# Run: 30, exploration: 0.15650920157696743, score: 9
# Scores: (min: 8, avg: 13.966666666666667, max: 40)
#
# Run: 31, exploration: 0.14885748713096328, score: 11
# Scores: (min: 8, avg: 13.870967741935484, max: 40)
#
# Run: 32, exploration: 0.14372497725712216, score: 8
# Scores: (min: 8, avg: 13.6875, max: 40)
#
# Run: 33, exploration: 0.13669828187021155, score: 11
# Scores: (min: 8, avg: 13.606060606060606, max: 40)
#
# Run: 34, exploration: 0.13001512070402377, score: 11
# Scores: (min: 8, avg: 13.529411764705882, max: 40)
#
# Run: 35, exploration: 0.12490462201997637, score: 9
# Scores: (min: 8, avg: 13.4, max: 40)
#
# Run: 36, exploration: 0.11999500148501063, score: 9
# Scores: (min: 8, avg: 13.277777777777779, max: 40)
#
# Run: 37, exploration: 0.11527836319047392, score: 9
# Scores: (min: 8, avg: 13.162162162162161, max: 40)
#
# Run: 38, exploration: 0.11019338598389174, score: 10
# Scores: (min: 8, avg: 13.078947368421053, max: 40)
#
# Run: 39, exploration: 0.10480604571960442, score: 11
# Scores: (min: 8, avg: 13.025641025641026, max: 40)
#
# Run: 40, exploration: 0.10018300685223579, score: 10
# Scores: (min: 8, avg: 12.95, max: 40)
#
# Run: 41, exploration: 0.09386293109673778, score: 14
# Scores: (min: 8, avg: 12.975609756097562, max: 40)
#
# Run: 42, exploration: 0.089273984641318, score: 11
# Scores: (min: 8, avg: 12.928571428571429, max: 40)
#
# Run: 43, exploration: 0.0832238973628649, score: 15
# Scores: (min: 8, avg: 12.976744186046512, max: 40)
#
# Run: 44, exploration: 0.07416156859737154, score: 24
# Scores: (min: 8, avg: 13.227272727272727, max: 40)
#
# Run: 45, exploration: 0.052741004581916356, score: 69
# Scores: (min: 8, avg: 14.466666666666667, max: 69)
#
# Run: 46, exploration: 0.04359387414694703, score: 39
# Scores: (min: 8, avg: 15, max: 69)
#
# Run: 47, exploration: 0.04146257532741124, score: 11
# Scores: (min: 8, avg: 14.914893617021276, max: 69)
#
# Run: 48, exploration: 0.034443736736092176, score: 38
# Scores: (min: 8, avg: 15.395833333333334, max: 69)
#
# Run: 49, exploration: 0.02861305625559891, score: 38
# Scores: (min: 8, avg: 15.857142857142858, max: 69)
#
# Run: 50, exploration: 0.023769400938086327, score: 38
# Scores: (min: 8, avg: 16.3, max: 69)
#
# Run: 51, exploration: 0.020145585821044927, score: 34
# Scores: (min: 8, avg: 16.647058823529413, max: 69)
#
# Run: 52, exploration: 0.01707424722777892, score: 34
# Scores: (min: 8, avg: 16.98076923076923, max: 69)
#
# Run: 53, exploration: 0.014112977003416188, score: 39
# Scores: (min: 8, avg: 17.39622641509434, max: 69)
#
# Run: 54, exploration: 0.01202146005600684, score: 33
# Scores: (min: 8, avg: 17.685185185185187, max: 69)
#
# Run: 55, exploration: 0.010137759008060509, score: 35
# Scores: (min: 8, avg: 18, max: 69)
#
# Run: 56, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 18.357142857142858, max: 69)
#
# Run: 57, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 18.56140350877193, max: 69)
#
# Run: 58, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 18.862068965517242, max: 69)
#
# Run: 59, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 19.305084745762713, max: 69)
#
# Run: 60, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 19.65, max: 69)
#
# Run: 61, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 20.016393442622952, max: 69)
#
# Run: 62, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 20.612903225806452, max: 69)
#
# Run: 63, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 21.11111111111111, max: 69)
#
# Run: 64, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 21.625, max: 69)
#
# Run: 65, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 22.06153846153846, max: 69)
#
# Run: 66, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 22.40909090909091, max: 69)
#
# Run: 67, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 22.98507462686567, max: 69)
#
# Run: 68, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 23.5, max: 69)
#
# Run: 69, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 24.44927536231884, max: 89)
#
# Run: 70, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 25.228571428571428, max: 89)
#
# Run: 71, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 25.887323943661972, max: 89)
#
# Run: 72, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 26.61111111111111, max: 89)
#
# Run: 73, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 26.753424657534246, max: 89)
#
# Run: 74, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 27.175675675675677, max: 89)
#
# Run: 75, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 27.386666666666667, max: 89)
#
# Run: 76, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 27.86842105263158, max: 89)
#
# Run: 77, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 29.16883116883117, max: 128)
#
# Run: 78, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 29.71794871794872, max: 128)
#
# Run: 79, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 30.734177215189874, max: 128)
#
# Run: 80, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 31.675, max: 128)
#
# Run: 81, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 32.51851851851852, max: 128)
#
# Run: 82, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 33.707317073170735, max: 130)
#
# Run: 83, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 34.036144578313255, max: 130)
#
# Run: 84, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 34.666666666666664, max: 130)
#
# Run: 85, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 35.36470588235294, max: 130)
#
# Run: 86, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 35.906976744186046, max: 130)
# Run: 87, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 37.18390804597701, max: 147)
#
# Run: 88, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 38.20454545454545, max: 147)
#
# Run: 89, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 38.62921348314607, max: 147)
#
# Run: 90, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 39.4, max: 147)
#
# Run: 91, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 41.2967032967033, max: 212)
#
# Run: 92, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 42.19565217391305, max: 212)
#
# Run: 93, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 43.16129032258065, max: 212)
#
# Run: 94, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 43.47872340425532, max: 212)
#
# Run: 95, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 44.04210526315789, max: 212)
#
# Run: 96, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 44.09375, max: 212)
#
# Run: 97, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 44.402061855670105, max: 212)
#
# Run: 98, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 44.51020408163265, max: 212)
#
# Run: 99, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 44.4040404040404, max: 212)
#
# Run: 100, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 45.78, max: 212)
#
# Run: 101, exploration: 0.01, score: 229
# Scores: (min: 8, avg: 47.67, max: 229)
#
# Run: 102, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 48.17, max: 229)
#
# Run: 103, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 49.19, max: 229)
#
# Run: 104, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 49.87, max: 229)
#
# Run: 105, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 50.75, max: 229)
#
# Run: 106, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 51.4, max: 229)
#
# Run: 107, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 52.36, max: 229)
#
# Run: 108, exploration: 0.01, score: 236
# Scores: (min: 8, avg: 54.56, max: 236)
#
# Run: 109, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 56.37, max: 236)
#
# Run: 110, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 57.5, max: 236)
#
# Run: 111, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 59.31, max: 236)
#
# Run: 112, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 61.24, max: 236)
#
# Run: 113, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 62.92, max: 236)
#
# Run: 114, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 64.48, max: 236)
#
# Run: 115, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 65.66, max: 236)
#
# Run: 116, exploration: 0.01, score: 250
# Scores: (min: 8, avg: 68, max: 250)
#
# Run: 117, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 69.76, max: 250)
#
# Run: 118, exploration: 0.01, score: 347
# Scores: (min: 8, avg: 73.14, max: 347)
#
# Run: 119, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 76.07, max: 347)
#
# Run: 120, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 77.41, max: 347)
#
# Run: 121, exploration: 0.01, score: 301
# Scores: (min: 8, avg: 80.31, max: 347)
#
# Run: 122, exploration: 0.01, score: 284
# Scores: (min: 8, avg: 83.07, max: 347)
#
# Run: 123, exploration: 0.01, score: 285
# Scores: (min: 8, avg: 85.81, max: 347)
#
# Run: 124, exploration: 0.01, score: 421
# Scores: (min: 8, avg: 89.91, max: 421)
#
# Run: 125, exploration: 0.01, score: 485
# Scores: (min: 8, avg: 94.67, max: 485)
#
# Run: 126, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 99.59, max: 500)
#
# Run: 127, exploration: 0.01, score: 286
# Scores: (min: 8, avg: 102.34, max: 500)
#
# Run: 128, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 107.23, max: 500)
#
# Run: 129, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 112.11, max: 500)
#
# Run: 130, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 113.63, max: 500)
#
# Run: 131, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 114.74, max: 500)
#
# Run: 132, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 114.77, max: 500)
#
# Run: 133, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 119.66, max: 500)
#
# Run: 134, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 124.55, max: 500)
#
# Run: 135, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 129.46, max: 500)
#
# Run: 136, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 134.37, max: 500)
#
# Run: 137, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 139.28, max: 500)
#
# Run: 138, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 144.18, max: 500)
#
# Run: 139, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 149.07, max: 500)
#
# Run: 140, exploration: 0.01, score: 318
# Scores: (min: 11, avg: 152.15, max: 500)
#
# Run: 141, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 157.01, max: 500)
#
# Run: 142, exploration: 0.01, score: 372
# Scores: (min: 11, avg: 160.62, max: 500)
#
# Run: 143, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 165.47, max: 500)
#
# Run: 144, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 170.23, max: 500)
#
# Run: 145, exploration: 0.01, score: 268
# Scores: (min: 11, avg: 172.22, max: 500)
#
# Run: 146, exploration: 0.01, score: 191
# Scores: (min: 11, avg: 173.74, max: 500)
#
# Run: 147, exploration: 0.01, score: 354
# Scores: (min: 11, avg: 177.17, max: 500)
#
# Run: 148, exploration: 0.01, score: 236
# Scores: (min: 11, avg: 179.15, max: 500)
#
# Run: 149, exploration: 0.01, score: 236
# Scores: (min: 11, avg: 181.13, max: 500)
#
# Run: 150, exploration: 0.01, score: 284
# Scores: (min: 11, avg: 183.59, max: 500)
#
# Run: 151, exploration: 0.01, score: 313
# Scores: (min: 11, avg: 186.38, max: 500)
#
# Run: 152, exploration: 0.01, score: 416
# Scores: (min: 11, avg: 190.2, max: 500)
#
# Run: 153, exploration: 0.01, score: 349
# Scores: (min: 11, avg: 193.3, max: 500)
#
# Run: 154, exploration: 0.01, score: 304
# Scores: (min: 11, avg: 196.01, max: 500)
#
# Solved in 54 runs, 154 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-5-989244214f60> in cartpole()
#      86             if terminal:
#      87                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 88                 score_logger.add_score(step, run)
#      89                 break
#      90             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# The following is an analysis of how reinforcement learning concepts apply to the cartpole problem, how experience replay is applied to the cartpole problem, and how neural networks are used in deep Q-learning.
# <br><br>**Explain how reinforcement learning concepts apply to the cartpole problem.**
# <br><br>•	**What is the goal of the agent in this case?**
# <br><br>The goal of the agent in this case is to keep the cartpole balanced and prevent it from falling over, by applying the appropriate forces to the cartpole’s pivot point (Surma, 2018).
# <br><br>•	**What are the various state values?**
# <br><br>According to Surma (2018), the observation space is the possible state values, which includes the cart position, cart velocity, pole angle, and pole velocity at the tip. The ranges for each are as follows:
# <br><br>Cart Position: (-4.8, 4.8)
# <br>Cart Velocity: (-Infinity, Infinity)
# <br>Pole Angle: (-24 degrees, 24 degrees)
# <br>Pole Velocity At Tip: (-Infinity, Infinity)
# <br><br>•	**What are the possible actions that can be performed?**
# <br><br>There are only two possible actions that can occur to keep the cartpole balanced and that is to either push the cart to the right or to the left (Surma, 2018).
# <br><br>•	**What reinforcement algorithm is used for this problem?**
# <br><br>The reinforcement algorithm that is used for this problem is the Deep Q-Learning (DQN) algorithm, which is a technique where given a circumstance or observation, the goal is to choose the best action (Surma, 2018).
# <br><br>**Analyze how experience replay is applied to the cartpole problem.**
# <br><br>•	**How does experience replay work in this algorithm?**
# <br><br>First, in Deep Q-learning, every possible action for observations has its own Q value, which is the quality of any given move (Surma, 2018). Inspired biologically, experience replay samples past experiences (from memory) and updates each entry’s Q value, which reduces the correlation between subsequent actions (Surma, 2018). Essentially, because of experience replay, instead of getting rid of past experiences, the experiences are stored in memory, which are then reused for training.
# <br><br>•	**What is the effect of introducing a discount factor for calculating the future rewards?**
# <br><br>The reason why a discount factor is introduced is because it determines the importance of future rewards (Venkatachalam, 2019). If this value is set to zero, only immediate rewards would be considered over future rewards. Increasing this value closer to one helps to balance short-term gains vs. future or long-term benefits, however, this can prevent conversion (Baeldung, 2023).
# <br><br>**Analyze how neural networks are used in deep Q-learning.**
# <br><br>•	**Explain the neural network architecture that is used in the cartpole problem.**
# <br><br>In the cartpole problem, a Deep Q-learning algorithm uses a deep neural network to approximate values by feeding the initial state into the network, which then, based on the Q table, calculates all possible actions, which are then generated as the output. (Singh, 2024). Past experiences are stored in memory, and the future action is dependent on the maximum value output of the Q-network (Singh, 2024).
# <br><br>•	**How does the neural network make the Q-Learning algorithm more efficient?**
# <br><br>In the Q-learning algorithm, using the Q-value iteration, the Q-table is computed containing all Q-values of any state-action pair (Amine, 2020). Because every state-action pair is stored, while this could work well for finite states and action spaces, it would not work well for significantly larger spaces (Amine, 2020). This is where implementing a deep neural network enables us to make the Q-learning algorithm more efficient because of their efficiency to approximate functions (Amine, 2020). Using the deep neural network to approximate the Q-value function, allows us to deal with continuous spaces without problem (Amine, 2020).
# <br><br>•	**What differences do you see in the algorithm performance when you increase or decrease the learning rate?**
# <br><br>In my last experiment, experiment 4, I chose to only modify the learning rate by decreasing it from 0.001 to 0.0008. In the first code block where no changes were made to the code, it solved the cartpole problem in 340 runs with a total of 440 runs. In experiment 4 where I decreased the learning rate by a small amount, it was able to solve the cartpole problem in 54 runs with a total of 154 runs. However, any time I tried making a significant change in the learning rate such as decreasing it to 0.0001 or increasing it to 0.01 or even 0.005, I observed drops in efficiency. The model would try to run for hundreds of epochs without solving the problem.
# <br><br>The learning rate is used in neural networks to determine how quickly a model is adapted to a problem and is often represented as a small value typically in the range of 0.0 to 1.0 (Brownlee, 2020). Decreasing the learning rate requires more training epochs since smaller changes are being made to the weights after each update, and increasing the learning rate results in more rapid changes to the weights, requiring a smaller number of training epochs (Brownlee, 2020). Having a learning rate that is too high can cause the network to converge too fast, which would lead to a solution that is suboptimal, and having a learning rate that is too small could cause the process to get stuck (Brownlee, 2020).
#
# References:
# <br><br>Amine, A. (2020, December 19). Deep Q-Networks: from theory to implementation. Medium. https://towardsdatascience.com/deep-q-networks-theory-and-implementation-37543f60dd67
# <br><br>Baeldung. (2023, March 24). Epsilon-Greedy Q-learning. https://www.baeldung.com/cs/epsilon-greedy-q-learning
# <br><br>Brownlee, J. (2020, September 12). Understand the Impact of Learning Rate on Neural Network Performance. Machine Learning Mastery. https://machinelearningmastery.com/understand-the-dynamics-of-learning-rate-on-deep-learning-neural-networks/
# <br><br>Singh, S. (2024). How Are Neural Networks Used in Deep Q-Learning? Turing. https://www.turing.com/kb/how-are-neural-networks-used-in-deep-q-learning
# <br><br>Surma, G. (2018, September 26). Cartpole - Introduction to Reinforcement Learning (DQN - Deep Q-Learning). Medium. https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
# <br><br>Venkatachalam, M. (2019, October 2). Q-Learning – An introduction through a simple table based implementation with learning rate, discount factor and exploration. gotensor. https://gotensor.com/2019/10/02/q-learning-an-introduction-through-a-simple-table-based-implementation-with-learning-rate-discount-factor-and-exploration/
